# %% [markdown]
# Another interpreter. We can represent the complete state with a dict; let's use a default dict so that we can initialise states to 0:

# %%
from collections import defaultdict
import re

# %% [markdown]
# We need a most recent value for the `rcv` instruction, so let's define a state as the triple `[R, S, C]`, where `R` is the most recent frequency, `S` is the ddict of the states, and `C` is the index of the current command. (List rather than tuple, so that we can take advantage of its mutability.)

# %% [markdown]
# So let's define a function which takes a state triple and a command, and updates the state accordingly.

# %%
def apply_command(command_str, stateIn):
    '''
    Updates stateIn with the command command_str
    '''
    
    # Useful to have a local function to check for ints:
    # (Could use exceptions, but I prefer not to if possible)
    def is_int(stringIn_str):
        '''
        True if stringIn_str can be converted to int
        '''
        if re.match('^\-?\d+$', stringIn_str):
            return True
        else:
            return False
    
    command_ls=command_str.strip().split()
    if command_ls[0]=='set':
        # If second argument is non-integral, treat it
        # as a ddict index
        if is_int(command_ls[2]):
            stateIn[1][command_ls[1]]=int(command_ls[2])
        else:
            stateIn[1][command_ls[1]]=stateIn[1][command_ls[2]]
        # Advance the command line
        stateIn[2]+=1
            
    elif command_ls[0]=='snd':
        # Play sound and set rcv to that frequency
        # PLAY SOUND!!
        if is_int(command_ls[1]):
            stateIn[0]=int(command_ls[1])
        else:
            stateIn[0]=stateIn[1][command_ls[1]]
        # Advance the command line
        stateIn[2]+=1
            
    elif command_ls[0]=='add':
        v=stateIn[1][command_ls[1]]
        if is_int(command_ls[2]):
            stateIn[1][command_ls[1]]=v+int(command_ls[2])
        else:
            stateIn[1][command_ls[1]]=v+stateIn[1][command_ls[2]]
        # Advance the command line
        stateIn[2]+=1

    elif command_ls[0]=='mul':
        v=stateIn[1][command_ls[1]]
        if is_int(command_ls[2]):
            stateIn[1][command_ls[1]]=v*int(command_ls[2])
        else:
            stateIn[1][command_ls[1]]=v*stateIn[1][command_ls[2]]
        # Advance the command line
        stateIn[2]+=1

    elif command_ls[0]=='mod':
        v=stateIn[1][command_ls[1]]
        if is_int(command_ls[2]):
            stateIn[1][command_ls[1]]=v%int(command_ls[2])
        else:
            stateIn[1][command_ls[1]]=v%stateIn[1][command_ls[2]]
        # Advance the command line
        stateIn[2]+=1

    elif command_ls[0]=='jgz':
        if is_int(command_ls[1]):
            v=int(command_ls[1])
        else:
            v=stateIn[1][command_ls[1]]
        # Jump if v>0
        if v>0:
            if is_int(command_ls[2]):
                stateIn[2]+=int(command_ls[2])
            else:
                stateIn[2]+=stateIn[1][command_ls[2]]
        # else just go forward 1:
        else:
            stateIn[2]+=1
    
    # Not clear what recovery is at the moment, so 
    # let's just print the output. Actually, we can
    # also return True in this case:
    elif command_ls[0]=='rcv':
        if is_int(command_ls[1]):
            v=int(command_ls[1])
        else:
            v=stateIn[1][command_ls[1]]
        # recover if v!=0
        if not v==0:
            print(stateIn[0])

            # Then advance 1 and return True:    
            stateIn[2]+=1
            return True
        stateIn[2]+=1

    else:
        raise ValueError("Command not recognised")
            
    return False

# %% [markdown]
# Set the test input:

# %%
testInput_str='''
set a 1
add a 2
mul a a
mod a 5
snd a
set a 0
rcv a
jgz a -1
set a 1
jgz a -2
'''

# %% [markdown]
# Let's try to apply the instructions:

# %%
state=[0, defaultdict(int), 0]
running_bl=True
commands_ls=testInput_str.strip().split('\n')

while running_bl:
    print(state)
    print(commands_ls[state[2]])
    t=apply_command(commands_ls[state[2]], state)
    if state[2]<0 or state[2]>=len(commands_ls) or t:
        running_bl=False
# Out:
# [0, defaultdict(<class 'int'>, {}), 0]
# set a 1
# [0, defaultdict(<class 'int'>, {'a': 1}), 1]
# add a 2
# [0, defaultdict(<class 'int'>, {'a': 3}), 2]
# mul a a
# [0, defaultdict(<class 'int'>, {'a': 9}), 3]
# mod a 5
# [0, defaultdict(<class 'int'>, {'a': 4}), 4]
# snd a
# [4, defaultdict(<class 'int'>, {'a': 4}), 5]
# set a 0
# [4, defaultdict(<class 'int'>, {'a': 0}), 6]
# rcv a
# [4, defaultdict(<class 'int'>, {'a': 0}), 7]
# jgz a -1
# [4, defaultdict(<class 'int'>, {'a': 0}), 8]
# set a 1
# [4, defaultdict(<class 'int'>, {'a': 1}), 9]
# jgz a -2
# [4, defaultdict(<class 'int'>, {'a': 1}), 7]
# jgz a -1
# [4, defaultdict(<class 'int'>, {'a': 1}), 6]
# rcv a
# 4

# %% [markdown]
# Good! Now try with the puzzle input:

# %%
with open('data/day18.txt') as fIn:
    puzzleInput_str=fIn.read()

state=[0, defaultdict(int), 0]
running_bl=True
commands_ls=puzzleInput_str.strip().split('\n')

while running_bl:
    print(state)
    print(commands_ls[state[2]])
    t=apply_command(commands_ls[state[2]], state)
    if state[2]<0 or state[2]>=len(commands_ls) or t:
        running_bl=False
# Out:
# [0, defaultdict(<class 'int'>, {}), 0]
# set i 31
# [0, defaultdict(<class 'int'>, {'i': 31}), 1]
# set a 1
# [0, defaultdict(<class 'int'>, {'i': 31, 'a': 1}), 2]
# mul p 17
# [0, defaultdict(<class 'int'>, {'i': 31, 'a': 1, 'p': 0}), 3]
# jgz p p
# [0, defaultdict(<class 'int'>, {'i': 31, 'a': 1, 'p': 0}), 4]
# mul a 2
# [0, defaultdict(<class 'int'>, {'i': 31, 'a': 2, 'p': 0}), 5]
# add i -1
# [0, defaultdict(<class 'int'>, {'i': 30, 'a': 2, 'p': 0}), 6]
# jgz i -2
# [0, defaultdict(<class 'int'>, {'i': 30, 'a': 2, 'p': 0}), 4]
# mul a 2
# [0, defaultdict(<class 'int'>, {'i': 30, 'a': 4, 'p': 0}), 5]
# add i -1
# [0, defaultdict(<class 'int'>, {'i': 29, 'a': 4, 'p': 0}), 6]
# jgz i -2
# [0, defaultdict(<class 'int'>, {'i': 29, 'a': 4, 'p': 0}), 4]
# mul a 2
# [0, defaultdict(<class 'int'>, {'i': 29, 'a': 8, 'p': 0}), 5]
# add i -1
# [0, defaultdict(<class 'int'>, {'i': 28, 'a': 8, 'p': 0}), 6]
# jgz i -2
# [0, defaultdict(<class 'int'>, {'i': 28, 'a': 8, 'p': 0}), 4]
# mul a 2
# [0, defaultdict(<class 'int'>, {'i': 28, 'a': 16, 'p': 0}), 5]
# add i -1
# [0, defaultdict(<class 'int'>, {'i': 27, 'a': 16, 'p': 0}), 6]
# jgz i -2
# [0, defaultdict(<class 'int'>, {'i': 27, 'a': 16, 'p': 0}), 4]
# mul a 2
# [0, defaultdict(<class 'int'>, {'i': 27, 'a': 32, 'p': 0}), 5]
# add i -1
# [0, defaultdict(<class 'int'>, {'i': 26, 'a': 32, 'p': 0}), 6]
# jgz i -2
# [0, defaultdict(<class 'int'>, {'i': 26, 'a': 32, 'p': 0}), 4]
# mul a 2
# [0, defaultdict(<class 'int'>, {'i': 26, 'a': 64, 'p': 0}), 5]
# add i -1
# [0, defaultdict(<class 'int'>, {'i': 25, 'a': 64, 'p': 0}), 6]
# jgz i -2
# [0, defaultdict(<class 'int'>, {'i': 25, 'a': 64, 'p': 0}), 4]
# mul a 2
# [0, defaultdict(<class 'int'>, {'i': 25, 'a': 128, 'p': 0}), 5]
# add i -1
# [0, defaultdict(<class 'int'>, {'i': 24, 'a': 128, 'p': 0}), 6]
# jgz i -2
# [0, defaultdict(<class 'int'>, {'i': 24, 'a': 128, 'p': 0}), 4]
# mul a 2
# [0, defaultdict(<class 'int'>, {'i': 24, 'a': 256, 'p': 0}), 5]
# add i -1
# [0, defaultdict(<class 'int'>, {'i': 23, 'a': 256, 'p': 0}), 6]
# jgz i -2
# [0, defaultdict(<class 'int'>, {'i': 23, 'a': 256, 'p': 0}), 4]
# mul a 2
# [0, defaultdict(<class 'int'>, {'i': 23, 'a': 512, 'p': 0}), 5]
# add i -1
# [0, defaultdict(<class 'int'>, {'i': 22, 'a': 512, 'p': 0}), 6]
# jgz i -2
# [0, defaultdict(<class 'int'>, {'i': 22, 'a': 512, 'p': 0}), 4]
# mul a 2
# [0, defaultdict(<class 'int'>, {'i': 22, 'a': 1024, 'p': 0}), 5]
# add i -1
# [0, defaultdict(<class 'int'>, {'i': 21, 'a': 1024, 'p': 0}), 6]
# jgz i -2
# [0, defaultdict(<class 'int'>, {'i': 21, 'a': 1024, 'p': 0}), 4]
# mul a 2
# [0, defaultdict(<class 'int'>, {'i': 21, 'a': 2048, 'p': 0}), 5]
# add i -1
# [0, defaultdict(<class 'int'>, {'i': 20, 'a': 2048, 'p': 0}), 6]
# jgz i -2
# [0, defaultdict(<class 'int'>, {'i': 20, 'a': 2048, 'p': 0}), 4]
# mul a 2
# [0, defaultdict(<class 'int'>, {'i': 20, 'a': 4096, 'p': 0}), 5]
# add i -1
# [0, defaultdict(<class 'int'>, {'i': 19, 'a': 4096, 'p': 0}), 6]
# jgz i -2
# [0, defaultdict(<class 'int'>, {'i': 19, 'a': 4096, 'p': 0}), 4]
# mul a 2
# [0, defaultdict(<class 'int'>, {'i': 19, 'a': 8192, 'p': 0}), 5]
# add i -1
# [0, defaultdict(<class 'int'>, {'i': 18, 'a': 8192, 'p': 0}), 6]
# jgz i -2
# [0, defaultdict(<class 'int'>, {'i': 18, 'a': 8192, 'p': 0}), 4]
# mul a 2
# [0, defaultdict(<class 'int'>, {'i': 18, 'a': 16384, 'p': 0}), 5]
# add i -1
# [0, defaultdict(<class 'int'>, {'i': 17, 'a': 16384, 'p': 0}), 6]
# jgz i -2
# [0, defaultdict(<class 'int'>, {'i': 17, 'a': 16384, 'p': 0}), 4]
# mul a 2
# [0, defaultdict(<class 'int'>, {'i': 17, 'a': 32768, 'p': 0}), 5]
# add i -1
# [0, defaultdict(<class 'int'>, {'i': 16, 'a': 32768, 'p': 0}), 6]
# jgz i -2
# [0, defaultdict(<class 'int'>, {'i': 16, 'a': 32768, 'p': 0}), 4]
# mul a 2
# [0, defaultdict(<class 'int'>, {'i': 16, 'a': 65536, 'p': 0}), 5]
# add i -1
# [0, defaultdict(<class 'int'>, {'i': 15, 'a': 65536, 'p': 0}), 6]
# jgz i -2
# [0, defaultdict(<class 'int'>, {'i': 15, 'a': 65536, 'p': 0}), 4]
# mul a 2
# [0, defaultdict(<class 'int'>, {'i': 15, 'a': 131072, 'p': 0}), 5]
# add i -1
# [0, defaultdict(<class 'int'>, {'i': 14, 'a': 131072, 'p': 0}), 6]
# jgz i -2
# [0, defaultdict(<class 'int'>, {'i': 14, 'a': 131072, 'p': 0}), 4]
# mul a 2
# [0, defaultdict(<class 'int'>, {'i': 14, 'a': 262144, 'p': 0}), 5]
# add i -1
# [0, defaultdict(<class 'int'>, {'i': 13, 'a': 262144, 'p': 0}), 6]
# jgz i -2
# [0, defaultdict(<class 'int'>, {'i': 13, 'a': 262144, 'p': 0}), 4]
# mul a 2
# [0, defaultdict(<class 'int'>, {'i': 13, 'a': 524288, 'p': 0}), 5]
# add i -1
# [0, defaultdict(<class 'int'>, {'i': 12, 'a': 524288, 'p': 0}), 6]
# jgz i -2
# [0, defaultdict(<class 'int'>, {'i': 12, 'a': 524288, 'p': 0}), 4]
# mul a 2
# [0, defaultdict(<class 'int'>, {'i': 12, 'a': 1048576, 'p': 0}), 5]
# add i -1
# [0, defaultdict(<class 'int'>, {'i': 11, 'a': 1048576, 'p': 0}), 6]
# jgz i -2
# [0, defaultdict(<class 'int'>, {'i': 11, 'a': 1048576, 'p': 0}), 4]
# mul a 2
# [0, defaultdict(<class 'int'>, {'i': 11, 'a': 2097152, 'p': 0}), 5]
# add i -1
# [0, defaultdict(<class 'int'>, {'i': 10, 'a': 2097152, 'p': 0}), 6]
# jgz i -2
# [0, defaultdict(<class 'int'>, {'i': 10, 'a': 2097152, 'p': 0}), 4]
# mul a 2
# [0, defaultdict(<class 'int'>, {'i': 10, 'a': 4194304, 'p': 0}), 5]
# add i -1
# [0, defaultdict(<class 'int'>, {'i': 9, 'a': 4194304, 'p': 0}), 6]
# jgz i -2
# [0, defaultdict(<class 'int'>, {'i': 9, 'a': 4194304, 'p': 0}), 4]
# mul a 2
# [0, defaultdict(<class 'int'>, {'i': 9, 'a': 8388608, 'p': 0}), 5]
# add i -1
# [0, defaultdict(<class 'int'>, {'i': 8, 'a': 8388608, 'p': 0}), 6]
# jgz i -2
# [0, defaultdict(<class 'int'>, {'i': 8, 'a': 8388608, 'p': 0}), 4]
# mul a 2
# [0, defaultdict(<class 'int'>, {'i': 8, 'a': 16777216, 'p': 0}), 5]
# add i -1
# [0, defaultdict(<class 'int'>, {'i': 7, 'a': 16777216, 'p': 0}), 6]
# jgz i -2
# [0, defaultdict(<class 'int'>, {'i': 7, 'a': 16777216, 'p': 0}), 4]
# mul a 2
# [0, defaultdict(<class 'int'>, {'i': 7, 'a': 33554432, 'p': 0}), 5]
# add i -1
# [0, defaultdict(<class 'int'>, {'i': 6, 'a': 33554432, 'p': 0}), 6]
# jgz i -2
# [0, defaultdict(<class 'int'>, {'i': 6, 'a': 33554432, 'p': 0}), 4]
# mul a 2
# [0, defaultdict(<class 'int'>, {'i': 6, 'a': 67108864, 'p': 0}), 5]
# add i -1
# [0, defaultdict(<class 'int'>, {'i': 5, 'a': 67108864, 'p': 0}), 6]
# jgz i -2
# [0, defaultdict(<class 'int'>, {'i': 5, 'a': 67108864, 'p': 0}), 4]
# mul a 2
# [0, defaultdict(<class 'int'>, {'i': 5, 'a': 134217728, 'p': 0}), 5]
# add i -1
# [0, defaultdict(<class 'int'>, {'i': 4, 'a': 134217728, 'p': 0}), 6]
# jgz i -2
# [0, defaultdict(<class 'int'>, {'i': 4, 'a': 134217728, 'p': 0}), 4]
# mul a 2
# [0, defaultdict(<class 'int'>, {'i': 4, 'a': 268435456, 'p': 0}), 5]
# add i -1
# [0, defaultdict(<class 'int'>, {'i': 3, 'a': 268435456, 'p': 0}), 6]
# jgz i -2
# [0, defaultdict(<class 'int'>, {'i': 3, 'a': 268435456, 'p': 0}), 4]
# mul a 2
# [0, defaultdict(<class 'int'>, {'i': 3, 'a': 536870912, 'p': 0}), 5]
# add i -1
# [0, defaultdict(<class 'int'>, {'i': 2, 'a': 536870912, 'p': 0}), 6]
# jgz i -2
# [0, defaultdict(<class 'int'>, {'i': 2, 'a': 536870912, 'p': 0}), 4]
# mul a 2
# [0, defaultdict(<class 'int'>, {'i': 2, 'a': 1073741824, 'p': 0}), 5]
# add i -1
# [0, defaultdict(<class 'int'>, {'i': 1, 'a': 1073741824, 'p': 0}), 6]
# jgz i -2
# [0, defaultdict(<class 'int'>, {'i': 1, 'a': 1073741824, 'p': 0}), 4]
# mul a 2
# [0, defaultdict(<class 'int'>, {'i': 1, 'a': 2147483648, 'p': 0}), 5]
# add i -1
# [0, defaultdict(<class 'int'>, {'i': 0, 'a': 2147483648, 'p': 0}), 6]
# jgz i -2
# [0, defaultdict(<class 'int'>, {'i': 0, 'a': 2147483648, 'p': 0}), 7]
# add a -1
# [0, defaultdict(<class 'int'>, {'i': 0, 'a': 2147483647, 'p': 0}), 8]
# set i 127
# [0, defaultdict(<class 'int'>, {'i': 127, 'a': 2147483647, 'p': 0}), 9]
# set p 826
# [0, defaultdict(<class 'int'>, {'i': 127, 'a': 2147483647, 'p': 826}), 10]
# mul p 8505
# [0, defaultdict(<class 'int'>, {'i': 127, 'a': 2147483647, 'p': 7025130}), 11]
# mod p a
# [0, defaultdict(<class 'int'>, {'i': 127, 'a': 2147483647, 'p': 7025130}), 12]
# mul p 129749
# [0, defaultdict(<class 'int'>, {'i': 127, 'a': 2147483647, 'p': 911503592370}), 13]
# add p 12345
# [0, defaultdict(<class 'int'>, {'i': 127, 'a': 2147483647, 'p': 911503604715}), 14]
# mod p a
# [0, defaultdict(<class 'int'>, {'i': 127, 'a': 2147483647, 'p': 970538387}), 15]
# set b p
# [0, defaultdict(<class 'int'>, {'i': 127, 'a': 2147483647, 'p': 970538387, 'b': 970538387}), 16]
# mod b 10000
# [0, defaultdict(<class 'int'>, {'i': 127, 'a': 2147483647, 'p': 970538387, 'b': 8387}), 17]
# snd b
# [8387, defaultdict(<class 'int'>, {'i': 127, 'a': 2147483647, 'p': 970538387, 'b': 8387}), 18]
# add i -1
# [8387, defaultdict(<class 'int'>, {'i': 126, 'a': 2147483647, 'p': 970538387, 'b': 8387}), 19]
# jgz i -9
# [8387, defaultdict(<class 'int'>, {'i': 126, 'a': 2147483647, 'p': 970538387, 'b': 8387}), 10]
# mul p 8505
# [8387, defaultdict(<class 'int'>, {'i': 126, 'a': 2147483647, 'p': 8254428981435, 'b': 8387}), 11]
# mod p a
# [8387, defaultdict(<class 'int'>, {'i': 126, 'a': 2147483647, 'p': 1649326014, 'b': 8387}), 12]
# mul p 129749
# [8387, defaultdict(<class 'int'>, {'i': 126, 'a': 2147483647, 'p': 213998400990486, 'b': 8387}), 13]
# add p 12345
# [8387, defaultdict(<class 'int'>, {'i': 126, 'a': 2147483647, 'p': 213998401002831, 'b': 8387}), 14]
# mod p a
# [8387, defaultdict(<class 'int'>, {'i': 126, 'a': 2147483647, 'p': 1655579281, 'b': 8387}), 15]
# set b p
# [8387, defaultdict(<class 'int'>, {'i': 126, 'a': 2147483647, 'p': 1655579281, 'b': 1655579281}), 16]
# mod b 10000
# [8387, defaultdict(<class 'int'>, {'i': 126, 'a': 2147483647, 'p': 1655579281, 'b': 9281}), 17]
# snd b
# [9281, defaultdict(<class 'int'>, {'i': 126, 'a': 2147483647, 'p': 1655579281, 'b': 9281}), 18]
# add i -1
# [9281, defaultdict(<class 'int'>, {'i': 125, 'a': 2147483647, 'p': 1655579281, 'b': 9281}), 19]
# jgz i -9
# [9281, defaultdict(<class 'int'>, {'i': 125, 'a': 2147483647, 'p': 1655579281, 'b': 9281}), 10]
# mul p 8505
# [9281, defaultdict(<class 'int'>, {'i': 125, 'a': 2147483647, 'p': 14080701784905, 'b': 9281}), 11]
# mod p a
# [9281, defaultdict(<class 'int'>, {'i': 125, 'a': 2147483647, 'p': 1798995173, 'b': 9281}), 12]
# mul p 129749
# [9281, defaultdict(<class 'int'>, {'i': 125, 'a': 2147483647, 'p': 233417824701577, 'b': 9281}), 13]
# add p 12345
# [9281, defaultdict(<class 'int'>, {'i': 125, 'a': 2147483647, 'p': 233417824713922, 'b': 9281}), 14]
# mod p a
# [9281, defaultdict(<class 'int'>, {'i': 125, 'a': 2147483647, 'p': 1384670551, 'b': 9281}), 15]
# set b p
# [9281, defaultdict(<class 'int'>, {'i': 125, 'a': 2147483647, 'p': 1384670551, 'b': 1384670551}), 16]
# mod b 10000
# [9281, defaultdict(<class 'int'>, {'i': 125, 'a': 2147483647, 'p': 1384670551, 'b': 551}), 17]
# snd b
# [551, defaultdict(<class 'int'>, {'i': 125, 'a': 2147483647, 'p': 1384670551, 'b': 551}), 18]
# add i -1
# [551, defaultdict(<class 'int'>, {'i': 124, 'a': 2147483647, 'p': 1384670551, 'b': 551}), 19]
# jgz i -9
# [551, defaultdict(<class 'int'>, {'i': 124, 'a': 2147483647, 'p': 1384670551, 'b': 551}), 10]
# mul p 8505
# [551, defaultdict(<class 'int'>, {'i': 124, 'a': 2147483647, 'p': 11776623036255, 'b': 551}), 11]
# mod p a
# [551, defaultdict(<class 'int'>, {'i': 124, 'a': 2147483647, 'p': 1970199754, 'b': 551}), 12]
# mul p 129749
# [551, defaultdict(<class 'int'>, {'i': 124, 'a': 2147483647, 'p': 255631447881746, 'b': 551}), 13]
# add p 12345
# [551, defaultdict(<class 'int'>, {'i': 124, 'a': 2147483647, 'p': 255631447894091, 'b': 551}), 14]
# mod p a
# [551, defaultdict(<class 'int'>, {'i': 124, 'a': 2147483647, 'p': 1437006152, 'b': 551}), 15]
# set b p
# [551, defaultdict(<class 'int'>, {'i': 124, 'a': 2147483647, 'p': 1437006152, 'b': 1437006152}), 16]
# mod b 10000
# [551, defaultdict(<class 'int'>, {'i': 124, 'a': 2147483647, 'p': 1437006152, 'b': 6152}), 17]
# snd b
# [6152, defaultdict(<class 'int'>, {'i': 124, 'a': 2147483647, 'p': 1437006152, 'b': 6152}), 18]
# add i -1
# [6152, defaultdict(<class 'int'>, {'i': 123, 'a': 2147483647, 'p': 1437006152, 'b': 6152}), 19]
# jgz i -9
# [6152, defaultdict(<class 'int'>, {'i': 123, 'a': 2147483647, 'p': 1437006152, 'b': 6152}), 10]
# mul p 8505
# [6152, defaultdict(<class 'int'>, {'i': 123, 'a': 2147483647, 'p': 12221737322760, 'b': 6152}), 11]
# mod p a
# [6152, defaultdict(<class 'int'>, {'i': 123, 'a': 2147483647, 'p': 407887683, 'b': 6152}), 12]
# mul p 129749
# [6152, defaultdict(<class 'int'>, {'i': 123, 'a': 2147483647, 'p': 52923018981567, 'b': 6152}), 13]
# add p 12345
# [6152, defaultdict(<class 'int'>, {'i': 123, 'a': 2147483647, 'p': 52923018993912, 'b': 6152}), 14]
# mod p a
# [6152, defaultdict(<class 'int'>, {'i': 123, 'a': 2147483647, 'p': 431997244, 'b': 6152}), 15]
# set b p
# [6152, defaultdict(<class 'int'>, {'i': 123, 'a': 2147483647, 'p': 431997244, 'b': 431997244}), 16]
# mod b 10000
# [6152, defaultdict(<class 'int'>, {'i': 123, 'a': 2147483647, 'p': 431997244, 'b': 7244}), 17]
# snd b
# [7244, defaultdict(<class 'int'>, {'i': 123, 'a': 2147483647, 'p': 431997244, 'b': 7244}), 18]
# add i -1
# [7244, defaultdict(<class 'int'>, {'i': 122, 'a': 2147483647, 'p': 431997244, 'b': 7244}), 19]
# jgz i -9
# [7244, defaultdict(<class 'int'>, {'i': 122, 'a': 2147483647, 'p': 431997244, 'b': 7244}), 10]
# mul p 8505
# [7244, defaultdict(<class 'int'>, {'i': 122, 'a': 2147483647, 'p': 3674136560220, 'b': 7244}), 11]
# mod p a
# [7244, defaultdict(<class 'int'>, {'i': 122, 'a': 2147483647, 'p': 1939523850, 'b': 7244}), 12]
# mul p 129749
# [7244, defaultdict(<class 'int'>, {'i': 122, 'a': 2147483647, 'p': 251651280013650, 'b': 7244}), 13]
# add p 12345
# [7244, defaultdict(<class 'int'>, {'i': 122, 'a': 2147483647, 'p': 251651280025995, 'b': 7244}), 14]
# mod p a
# [7244, defaultdict(<class 'int'>, {'i': 122, 'a': 2147483647, 'p': 556335947, 'b': 7244}), 15]
# set b p
# [7244, defaultdict(<class 'int'>, {'i': 122, 'a': 2147483647, 'p': 556335947, 'b': 556335947}), 16]
# mod b 10000
# [7244, defaultdict(<class 'int'>, {'i': 122, 'a': 2147483647, 'p': 556335947, 'b': 5947}), 17]
# snd b
# [5947, defaultdict(<class 'int'>, {'i': 122, 'a': 2147483647, 'p': 556335947, 'b': 5947}), 18]
# add i -1
# [5947, defaultdict(<class 'int'>, {'i': 121, 'a': 2147483647, 'p': 556335947, 'b': 5947}), 19]
# jgz i -9
# [5947, defaultdict(<class 'int'>, {'i': 121, 'a': 2147483647, 'p': 556335947, 'b': 5947}), 10]
# mul p 8505
# [5947, defaultdict(<class 'int'>, {'i': 121, 'a': 2147483647, 'p': 4731637229235, 'b': 5947}), 11]
# mod p a
# [5947, defaultdict(<class 'int'>, {'i': 121, 'a': 2147483647, 'p': 730754894, 'b': 5947}), 12]
# mul p 129749
# [5947, defaultdict(<class 'int'>, {'i': 121, 'a': 2147483647, 'p': 94814716741606, 'b': 5947}), 13]
# add p 12345
# [5947, defaultdict(<class 'int'>, {'i': 121, 'a': 2147483647, 'p': 94814716753951, 'b': 5947}), 14]
# mod p a
# [5947, defaultdict(<class 'int'>, {'i': 121, 'a': 2147483647, 'p': 1166255254, 'b': 5947}), 15]
# set b p
# [5947, defaultdict(<class 'int'>, {'i': 121, 'a': 2147483647, 'p': 1166255254, 'b': 1166255254}), 16]
# mod b 10000
# [5947, defaultdict(<class 'int'>, {'i': 121, 'a': 2147483647, 'p': 1166255254, 'b': 5254}), 17]
# snd b
# [5254, defaultdict(<class 'int'>, {'i': 121, 'a': 2147483647, 'p': 1166255254, 'b': 5254}), 18]
# add i -1
# [5254, defaultdict(<class 'int'>, {'i': 120, 'a': 2147483647, 'p': 1166255254, 'b': 5254}), 19]
# jgz i -9
# [5254, defaultdict(<class 'int'>, {'i': 120, 'a': 2147483647, 'p': 1166255254, 'b': 5254}), 10]
# mul p 8505
# [5254, defaultdict(<class 'int'>, {'i': 120, 'a': 2147483647, 'p': 9919000935270, 'b': 5254}), 11]
# mod p a
# [5254, defaultdict(<class 'int'>, {'i': 120, 'a': 2147483647, 'p': 1921453424, 'b': 5254}), 12]
# mul p 129749
# [5254, defaultdict(<class 'int'>, {'i': 120, 'a': 2147483647, 'p': 249306660310576, 'b': 5254}), 13]
# add p 12345
# [5254, defaultdict(<class 'int'>, {'i': 120, 'a': 2147483647, 'p': 249306660322921, 'b': 5254}), 14]
# mod p a
# [5254, defaultdict(<class 'int'>, {'i': 120, 'a': 2147483647, 'p': 988775397, 'b': 5254}), 15]
# set b p
# [5254, defaultdict(<class 'int'>, {'i': 120, 'a': 2147483647, 'p': 988775397, 'b': 988775397}), 16]
# mod b 10000
# [5254, defaultdict(<class 'int'>, {'i': 120, 'a': 2147483647, 'p': 988775397, 'b': 5397}), 17]
# snd b
# [5397, defaultdict(<class 'int'>, {'i': 120, 'a': 2147483647, 'p': 988775397, 'b': 5397}), 18]
# add i -1
# [5397, defaultdict(<class 'int'>, {'i': 119, 'a': 2147483647, 'p': 988775397, 'b': 5397}), 19]
# jgz i -9
# [5397, defaultdict(<class 'int'>, {'i': 119, 'a': 2147483647, 'p': 988775397, 'b': 5397}), 10]
# mul p 8505
# [5397, defaultdict(<class 'int'>, {'i': 119, 'a': 2147483647, 'p': 8409534751485, 'b': 5397}), 11]
# mod p a
# [5397, defaultdict(<class 'int'>, {'i': 119, 'a': 2147483647, 'p': 2136273480, 'b': 5397}), 12]
# mul p 129749
# [5397, defaultdict(<class 'int'>, {'i': 119, 'a': 2147483647, 'p': 277179347756520, 'b': 5397}), 13]
# add p 12345
# [5397, defaultdict(<class 'int'>, {'i': 119, 'a': 2147483647, 'p': 277179347768865, 'b': 5397}), 14]
# mod p a
# [5397, defaultdict(<class 'int'>, {'i': 119, 'a': 2147483647, 'p': 1485966928, 'b': 5397}), 15]
# set b p
# [5397, defaultdict(<class 'int'>, {'i': 119, 'a': 2147483647, 'p': 1485966928, 'b': 1485966928}), 16]
# mod b 10000
# [5397, defaultdict(<class 'int'>, {'i': 119, 'a': 2147483647, 'p': 1485966928, 'b': 6928}), 17]
# snd b
# [6928, defaultdict(<class 'int'>, {'i': 119, 'a': 2147483647, 'p': 1485966928, 'b': 6928}), 18]
# add i -1
# [6928, defaultdict(<class 'int'>, {'i': 118, 'a': 2147483647, 'p': 1485966928, 'b': 6928}), 19]
# jgz i -9
# [6928, defaultdict(<class 'int'>, {'i': 118, 'a': 2147483647, 'p': 1485966928, 'b': 6928}), 10]
# mul p 8505
# [6928, defaultdict(<class 'int'>, {'i': 118, 'a': 2147483647, 'p': 12638148722640, 'b': 6928}), 11]
# mod p a
# [6928, defaultdict(<class 'int'>, {'i': 118, 'a': 2147483647, 'p': 207460045, 'b': 6928}), 12]
# mul p 129749
# [6928, defaultdict(<class 'int'>, {'i': 118, 'a': 2147483647, 'p': 26917733378705, 'b': 6928}), 13]
# add p 12345
# [6928, defaultdict(<class 'int'>, {'i': 118, 'a': 2147483647, 'p': 26917733391050, 'b': 6928}), 14]
# mod p a
# [6928, defaultdict(<class 'int'>, {'i': 118, 'a': 2147483647, 'p': 1173359552, 'b': 6928}), 15]
# set b p
# [6928, defaultdict(<class 'int'>, {'i': 118, 'a': 2147483647, 'p': 1173359552, 'b': 1173359552}), 16]
# mod b 10000
# [6928, defaultdict(<class 'int'>, {'i': 118, 'a': 2147483647, 'p': 1173359552, 'b': 9552}), 17]
# snd b
# [9552, defaultdict(<class 'int'>, {'i': 118, 'a': 2147483647, 'p': 1173359552, 'b': 9552}), 18]
# add i -1
# [9552, defaultdict(<class 'int'>, {'i': 117, 'a': 2147483647, 'p': 1173359552, 'b': 9552}), 19]
# jgz i -9
# [9552, defaultdict(<class 'int'>, {'i': 117, 'a': 2147483647, 'p': 1173359552, 'b': 9552}), 10]
# mul p 8505
# [9552, defaultdict(<class 'int'>, {'i': 117, 'a': 2147483647, 'p': 9979422989760, 'b': 9552}), 11]
# mod p a
# [9552, defaultdict(<class 'int'>, {'i': 117, 'a': 2147483647, 'p': 66482151, 'b': 9552}), 12]
# mul p 129749
# [9552, defaultdict(<class 'int'>, {'i': 117, 'a': 2147483647, 'p': 8625992610099, 'b': 9552}), 13]
# add p 12345
# [9552, defaultdict(<class 'int'>, {'i': 117, 'a': 2147483647, 'p': 8625992622444, 'b': 9552}), 14]
# mod p a
# [9552, defaultdict(<class 'int'>, {'i': 117, 'a': 2147483647, 'p': 1698296092, 'b': 9552}), 15]
# set b p
# [9552, defaultdict(<class 'int'>, {'i': 117, 'a': 2147483647, 'p': 1698296092, 'b': 1698296092}), 16]
# mod b 10000
# [9552, defaultdict(<class 'int'>, {'i': 117, 'a': 2147483647, 'p': 1698296092, 'b': 6092}), 17]
# snd b
# [6092, defaultdict(<class 'int'>, {'i': 117, 'a': 2147483647, 'p': 1698296092, 'b': 6092}), 18]
# add i -1
# [6092, defaultdict(<class 'int'>, {'i': 116, 'a': 2147483647, 'p': 1698296092, 'b': 6092}), 19]
# jgz i -9
# [6092, defaultdict(<class 'int'>, {'i': 116, 'a': 2147483647, 'p': 1698296092, 'b': 6092}), 10]
# mul p 8505
# [6092, defaultdict(<class 'int'>, {'i': 116, 'a': 2147483647, 'p': 14444008262460, 'b': 6092}), 11]
# mod p a
# [6092, defaultdict(<class 'int'>, {'i': 116, 'a': 2147483647, 'p': 33252738, 'b': 6092}), 12]
# mul p 129749
# [6092, defaultdict(<class 'int'>, {'i': 116, 'a': 2147483647, 'p': 4314509502762, 'b': 6092}), 13]
# add p 12345
# [6092, defaultdict(<class 'int'>, {'i': 116, 'a': 2147483647, 'p': 4314509515107, 'b': 6092}), 14]
# mod p a
# [6092, defaultdict(<class 'int'>, {'i': 116, 'a': 2147483647, 'p': 214868284, 'b': 6092}), 15]
# set b p
# [6092, defaultdict(<class 'int'>, {'i': 116, 'a': 2147483647, 'p': 214868284, 'b': 214868284}), 16]
# mod b 10000
# [6092, defaultdict(<class 'int'>, {'i': 116, 'a': 2147483647, 'p': 214868284, 'b': 8284}), 17]
# snd b
# [8284, defaultdict(<class 'int'>, {'i': 116, 'a': 2147483647, 'p': 214868284, 'b': 8284}), 18]
# add i -1
# [8284, defaultdict(<class 'int'>, {'i': 115, 'a': 2147483647, 'p': 214868284, 'b': 8284}), 19]
# jgz i -9
# [8284, defaultdict(<class 'int'>, {'i': 115, 'a': 2147483647, 'p': 214868284, 'b': 8284}), 10]
# mul p 8505
# [8284, defaultdict(<class 'int'>, {'i': 115, 'a': 2147483647, 'p': 1827454755420, 'b': 8284}), 11]
# mod p a
# [8284, defaultdict(<class 'int'>, {'i': 115, 'a': 2147483647, 'p': 2093655470, 'b': 8284}), 12]
# mul p 129749
# [8284, defaultdict(<class 'int'>, {'i': 115, 'a': 2147483647, 'p': 271649703577030, 'b': 8284}), 13]
# add p 12345
# [8284, defaultdict(<class 'int'>, {'i': 115, 'a': 2147483647, 'p': 271649703589375, 'b': 8284}), 14]
# mod p a
# [8284, defaultdict(<class 'int'>, {'i': 115, 'a': 2147483647, 'p': 1612178463, 'b': 8284}), 15]
# set b p
# [8284, defaultdict(<class 'int'>, {'i': 115, 'a': 2147483647, 'p': 1612178463, 'b': 1612178463}), 16]
# mod b 10000
# [8284, defaultdict(<class 'int'>, {'i': 115, 'a': 2147483647, 'p': 1612178463, 'b': 8463}), 17]
# snd b
# [8463, defaultdict(<class 'int'>, {'i': 115, 'a': 2147483647, 'p': 1612178463, 'b': 8463}), 18]
# add i -1
# [8463, defaultdict(<class 'int'>, {'i': 114, 'a': 2147483647, 'p': 1612178463, 'b': 8463}), 19]
# jgz i -9
# [8463, defaultdict(<class 'int'>, {'i': 114, 'a': 2147483647, 'p': 1612178463, 'b': 8463}), 10]
# mul p 8505
# [8463, defaultdict(<class 'int'>, {'i': 114, 'a': 2147483647, 'p': 13711577827815, 'b': 8463}), 11]
# mod p a
# [8463, defaultdict(<class 'int'>, {'i': 114, 'a': 2147483647, 'p': 2042225367, 'b': 8463}), 12]
# mul p 129749
# [8463, defaultdict(<class 'int'>, {'i': 114, 'a': 2147483647, 'p': 264976699142883, 'b': 8463}), 13]
# add p 12345
# [8463, defaultdict(<class 'int'>, {'i': 114, 'a': 2147483647, 'p': 264976699155228, 'b': 8463}), 14]
# mod p a
# [8463, defaultdict(<class 'int'>, {'i': 114, 'a': 2147483647, 'p': 839435545, 'b': 8463}), 15]
# set b p
# [8463, defaultdict(<class 'int'>, {'i': 114, 'a': 2147483647, 'p': 839435545, 'b': 839435545}), 16]
# mod b 10000
# [8463, defaultdict(<class 'int'>, {'i': 114, 'a': 2147483647, 'p': 839435545, 'b': 5545}), 17]
# snd b
# [5545, defaultdict(<class 'int'>, {'i': 114, 'a': 2147483647, 'p': 839435545, 'b': 5545}), 18]
# add i -1
# [5545, defaultdict(<class 'int'>, {'i': 113, 'a': 2147483647, 'p': 839435545, 'b': 5545}), 19]
# jgz i -9
# [5545, defaultdict(<class 'int'>, {'i': 113, 'a': 2147483647, 'p': 839435545, 'b': 5545}), 10]
# mul p 8505
# [5545, defaultdict(<class 'int'>, {'i': 113, 'a': 2147483647, 'p': 7139399310225, 'b': 5545}), 11]
# mod p a
# [5545, defaultdict(<class 'int'>, {'i': 113, 'a': 2147483647, 'p': 1163667597, 'b': 5545}), 12]
# mul p 129749
# [5545, defaultdict(<class 'int'>, {'i': 113, 'a': 2147483647, 'p': 150984707043153, 'b': 5545}), 13]
# add p 12345
# [5545, defaultdict(<class 'int'>, {'i': 113, 'a': 2147483647, 'p': 150984707055498, 'b': 5545}), 14]
# mod p a
# [5545, defaultdict(<class 'int'>, {'i': 113, 'a': 2147483647, 'p': 1574285869, 'b': 5545}), 15]
# set b p
# [5545, defaultdict(<class 'int'>, {'i': 113, 'a': 2147483647, 'p': 1574285869, 'b': 1574285869}), 16]
# mod b 10000
# [5545, defaultdict(<class 'int'>, {'i': 113, 'a': 2147483647, 'p': 1574285869, 'b': 5869}), 17]
# snd b
# [5869, defaultdict(<class 'int'>, {'i': 113, 'a': 2147483647, 'p': 1574285869, 'b': 5869}), 18]
# add i -1
# [5869, defaultdict(<class 'int'>, {'i': 112, 'a': 2147483647, 'p': 1574285869, 'b': 5869}), 19]
# jgz i -9
# [5869, defaultdict(<class 'int'>, {'i': 112, 'a': 2147483647, 'p': 1574285869, 'b': 5869}), 10]
# mul p 8505
# [5869, defaultdict(<class 'int'>, {'i': 112, 'a': 2147483647, 'p': 13389301315845, 'b': 5869}), 11]
# mod p a
# [5869, defaultdict(<class 'int'>, {'i': 112, 'a': 2147483647, 'p': 1888260447, 'b': 5869}), 12]
# mul p 129749
# [5869, defaultdict(<class 'int'>, {'i': 112, 'a': 2147483647, 'p': 244999904737803, 'b': 5869}), 13]
# add p 12345
# [5869, defaultdict(<class 'int'>, {'i': 112, 'a': 2147483647, 'p': 244999904750148, 'b': 5869}), 14]
# mod p a
# [5869, defaultdict(<class 'int'>, {'i': 112, 'a': 2147483647, 'p': 2085398506, 'b': 5869}), 15]
# set b p
# [5869, defaultdict(<class 'int'>, {'i': 112, 'a': 2147483647, 'p': 2085398506, 'b': 2085398506}), 16]
# mod b 10000
# [5869, defaultdict(<class 'int'>, {'i': 112, 'a': 2147483647, 'p': 2085398506, 'b': 8506}), 17]
# snd b
# [8506, defaultdict(<class 'int'>, {'i': 112, 'a': 2147483647, 'p': 2085398506, 'b': 8506}), 18]
# add i -1
# [8506, defaultdict(<class 'int'>, {'i': 111, 'a': 2147483647, 'p': 2085398506, 'b': 8506}), 19]
# jgz i -9
# [8506, defaultdict(<class 'int'>, {'i': 111, 'a': 2147483647, 'p': 2085398506, 'b': 8506}), 10]
# mul p 8505
# [8506, defaultdict(<class 'int'>, {'i': 111, 'a': 2147483647, 'p': 17736314293530, 'b': 8506}), 11]
# mod p a
# [8506, defaultdict(<class 'int'>, {'i': 111, 'a': 2147483647, 'p': 246852957, 'b': 8506}), 12]
# mul p 129749
# [8506, defaultdict(<class 'int'>, {'i': 111, 'a': 2147483647, 'p': 32028924317793, 'b': 8506}), 13]
# add p 12345
# [8506, defaultdict(<class 'int'>, {'i': 111, 'a': 2147483647, 'p': 32028924330138, 'b': 8506}), 14]
# mod p a
# [8506, defaultdict(<class 'int'>, {'i': 111, 'a': 2147483647, 'p': 1353218780, 'b': 8506}), 15]
# set b p
# [8506, defaultdict(<class 'int'>, {'i': 111, 'a': 2147483647, 'p': 1353218780, 'b': 1353218780}), 16]
# mod b 10000
# [8506, defaultdict(<class 'int'>, {'i': 111, 'a': 2147483647, 'p': 1353218780, 'b': 8780}), 17]
# snd b
# [8780, defaultdict(<class 'int'>, {'i': 111, 'a': 2147483647, 'p': 1353218780, 'b': 8780}), 18]
# add i -1
# [8780, defaultdict(<class 'int'>, {'i': 110, 'a': 2147483647, 'p': 1353218780, 'b': 8780}), 19]
# jgz i -9
# [8780, defaultdict(<class 'int'>, {'i': 110, 'a': 2147483647, 'p': 1353218780, 'b': 8780}), 10]
# mul p 8505
# [8780, defaultdict(<class 'int'>, {'i': 110, 'a': 2147483647, 'p': 11509125723900, 'b': 8780}), 11]
# mod p a
# [8780, defaultdict(<class 'int'>, {'i': 110, 'a': 2147483647, 'p': 760859627, 'b': 8780}), 12]
# mul p 129749
# [8780, defaultdict(<class 'int'>, {'i': 110, 'a': 2147483647, 'p': 98720775743623, 'b': 8780}), 13]
# add p 12345
# [8780, defaultdict(<class 'int'>, {'i': 110, 'a': 2147483647, 'p': 98720775755968, 'b': 8780}), 14]
# mod p a
# [8780, defaultdict(<class 'int'>, {'i': 110, 'a': 2147483647, 'p': 952503378, 'b': 8780}), 15]
# set b p
# [8780, defaultdict(<class 'int'>, {'i': 110, 'a': 2147483647, 'p': 952503378, 'b': 952503378}), 16]
# mod b 10000
# [8780, defaultdict(<class 'int'>, {'i': 110, 'a': 2147483647, 'p': 952503378, 'b': 3378}), 17]
# snd b
# [3378, defaultdict(<class 'int'>, {'i': 110, 'a': 2147483647, 'p': 952503378, 'b': 3378}), 18]
# add i -1
# [3378, defaultdict(<class 'int'>, {'i': 109, 'a': 2147483647, 'p': 952503378, 'b': 3378}), 19]
# jgz i -9
# [3378, defaultdict(<class 'int'>, {'i': 109, 'a': 2147483647, 'p': 952503378, 'b': 3378}), 10]
# mul p 8505
# [3378, defaultdict(<class 'int'>, {'i': 109, 'a': 2147483647, 'p': 8101041229890, 'b': 3378}), 11]
# mod p a
# [3378, defaultdict(<class 'int'>, {'i': 109, 'a': 2147483647, 'p': 732913406, 'b': 3378}), 12]
# mul p 129749
# [3378, defaultdict(<class 'int'>, {'i': 109, 'a': 2147483647, 'p': 95094781515094, 'b': 3378}), 13]
# add p 12345
# [3378, defaultdict(<class 'int'>, {'i': 109, 'a': 2147483647, 'p': 95094781527439, 'b': 3378}), 14]
# mod p a
# [3378, defaultdict(<class 'int'>, {'i': 109, 'a': 2147483647, 'p': 2058154632, 'b': 3378}), 15]
# set b p
# [3378, defaultdict(<class 'int'>, {'i': 109, 'a': 2147483647, 'p': 2058154632, 'b': 2058154632}), 16]
# mod b 10000
# [3378, defaultdict(<class 'int'>, {'i': 109, 'a': 2147483647, 'p': 2058154632, 'b': 4632}), 17]
# snd b
# [4632, defaultdict(<class 'int'>, {'i': 109, 'a': 2147483647, 'p': 2058154632, 'b': 4632}), 18]
# add i -1
# [4632, defaultdict(<class 'int'>, {'i': 108, 'a': 2147483647, 'p': 2058154632, 'b': 4632}), 19]
# jgz i -9
# [4632, defaultdict(<class 'int'>, {'i': 108, 'a': 2147483647, 'p': 2058154632, 'b': 4632}), 10]
# mul p 8505
# [4632, defaultdict(<class 'int'>, {'i': 108, 'a': 2147483647, 'p': 17504605145160, 'b': 4632}), 11]
# mod p a
# [4632, defaultdict(<class 'int'>, {'i': 108, 'a': 2147483647, 'p': 465938463, 'b': 4632}), 12]
# mul p 129749
# [4632, defaultdict(<class 'int'>, {'i': 108, 'a': 2147483647, 'p': 60455049635787, 'b': 4632}), 13]
# add p 12345
# [4632, defaultdict(<class 'int'>, {'i': 108, 'a': 2147483647, 'p': 60455049648132, 'b': 4632}), 14]
# mod p a
# [4632, defaultdict(<class 'int'>, {'i': 108, 'a': 2147483647, 'p': 1237501435, 'b': 4632}), 15]
# set b p
# [4632, defaultdict(<class 'int'>, {'i': 108, 'a': 2147483647, 'p': 1237501435, 'b': 1237501435}), 16]
# mod b 10000
# [4632, defaultdict(<class 'int'>, {'i': 108, 'a': 2147483647, 'p': 1237501435, 'b': 1435}), 17]
# snd b
# [1435, defaultdict(<class 'int'>, {'i': 108, 'a': 2147483647, 'p': 1237501435, 'b': 1435}), 18]
# add i -1
# [1435, defaultdict(<class 'int'>, {'i': 107, 'a': 2147483647, 'p': 1237501435, 'b': 1435}), 19]
# jgz i -9
# [1435, defaultdict(<class 'int'>, {'i': 107, 'a': 2147483647, 'p': 1237501435, 'b': 1435}), 10]
# mul p 8505
# [1435, defaultdict(<class 'int'>, {'i': 107, 'a': 2147483647, 'p': 10524949704675, 'b': 1435}), 11]
# mod p a
# [1435, defaultdict(<class 'int'>, {'i': 107, 'a': 2147483647, 'p': 132350728, 'b': 1435}), 12]
# mul p 129749
# [1435, defaultdict(<class 'int'>, {'i': 107, 'a': 2147483647, 'p': 17172374607272, 'b': 1435}), 13]
# add p 12345
# [1435, defaultdict(<class 'int'>, {'i': 107, 'a': 2147483647, 'p': 17172374619617, 'b': 1435}), 14]
# mod p a
# [1435, defaultdict(<class 'int'>, {'i': 107, 'a': 2147483647, 'p': 1095378205, 'b': 1435}), 15]
# set b p
# [1435, defaultdict(<class 'int'>, {'i': 107, 'a': 2147483647, 'p': 1095378205, 'b': 1095378205}), 16]
# mod b 10000
# [1435, defaultdict(<class 'int'>, {'i': 107, 'a': 2147483647, 'p': 1095378205, 'b': 8205}), 17]
# snd b
# [8205, defaultdict(<class 'int'>, {'i': 107, 'a': 2147483647, 'p': 1095378205, 'b': 8205}), 18]
# add i -1
# [8205, defaultdict(<class 'int'>, {'i': 106, 'a': 2147483647, 'p': 1095378205, 'b': 8205}), 19]
# jgz i -9
# [8205, defaultdict(<class 'int'>, {'i': 106, 'a': 2147483647, 'p': 1095378205, 'b': 8205}), 10]
# mul p 8505
# [8205, defaultdict(<class 'int'>, {'i': 106, 'a': 2147483647, 'p': 9316191633525, 'b': 8205}), 11]
# mod p a
# [8205, defaultdict(<class 'int'>, {'i': 106, 'a': 2147483647, 'p': 407572839, 'b': 8205}), 12]
# mul p 129749
# [8205, defaultdict(<class 'int'>, {'i': 106, 'a': 2147483647, 'p': 52882168287411, 'b': 8205}), 13]
# add p 12345
# [8205, defaultdict(<class 'int'>, {'i': 106, 'a': 2147483647, 'p': 52882168299756, 'b': 8205}), 14]
# mod p a
# [8205, defaultdict(<class 'int'>, {'i': 106, 'a': 2147483647, 'p': 383492381, 'b': 8205}), 15]
# set b p
# [8205, defaultdict(<class 'int'>, {'i': 106, 'a': 2147483647, 'p': 383492381, 'b': 383492381}), 16]
# mod b 10000
# [8205, defaultdict(<class 'int'>, {'i': 106, 'a': 2147483647, 'p': 383492381, 'b': 2381}), 17]
# snd b
# [2381, defaultdict(<class 'int'>, {'i': 106, 'a': 2147483647, 'p': 383492381, 'b': 2381}), 18]
# add i -1
# [2381, defaultdict(<class 'int'>, {'i': 105, 'a': 2147483647, 'p': 383492381, 'b': 2381}), 19]
# jgz i -9
# [2381, defaultdict(<class 'int'>, {'i': 105, 'a': 2147483647, 'p': 383492381, 'b': 2381}), 10]
# mul p 8505
# [2381, defaultdict(<class 'int'>, {'i': 105, 'a': 2147483647, 'p': 3261602700405, 'b': 2381}), 11]
# mod p a
# [2381, defaultdict(<class 'int'>, {'i': 105, 'a': 2147483647, 'p': 1722524259, 'b': 2381}), 12]
# mul p 129749
# [2381, defaultdict(<class 'int'>, {'i': 105, 'a': 2147483647, 'p': 223495800080991, 'b': 2381}), 13]
# add p 12345
# [2381, defaultdict(<class 'int'>, {'i': 105, 'a': 2147483647, 'p': 223495800093336, 'b': 2381}), 14]
# mod p a
# [2381, defaultdict(<class 'int'>, {'i': 105, 'a': 2147483647, 'p': 734499105, 'b': 2381}), 15]
# set b p
# [2381, defaultdict(<class 'int'>, {'i': 105, 'a': 2147483647, 'p': 734499105, 'b': 734499105}), 16]
# mod b 10000
# [2381, defaultdict(<class 'int'>, {'i': 105, 'a': 2147483647, 'p': 734499105, 'b': 9105}), 17]
# snd b
# [9105, defaultdict(<class 'int'>, {'i': 105, 'a': 2147483647, 'p': 734499105, 'b': 9105}), 18]
# add i -1
# [9105, defaultdict(<class 'int'>, {'i': 104, 'a': 2147483647, 'p': 734499105, 'b': 9105}), 19]
# jgz i -9
# [9105, defaultdict(<class 'int'>, {'i': 104, 'a': 2147483647, 'p': 734499105, 'b': 9105}), 10]
# mul p 8505
# [9105, defaultdict(<class 'int'>, {'i': 104, 'a': 2147483647, 'p': 6246914888025, 'b': 9105}), 11]
# mod p a
# [9105, defaultdict(<class 'int'>, {'i': 104, 'a': 2147483647, 'p': 2032442549, 'b': 9105}), 12]
# mul p 129749
# [9105, defaultdict(<class 'int'>, {'i': 104, 'a': 2147483647, 'p': 263707388290201, 'b': 9105}), 13]
# add p 12345
# [9105, defaultdict(<class 'int'>, {'i': 104, 'a': 2147483647, 'p': 263707388302546, 'b': 9105}), 14]
# mod p a
# [9105, defaultdict(<class 'int'>, {'i': 104, 'a': 2147483647, 'p': 691418240, 'b': 9105}), 15]
# set b p
# [9105, defaultdict(<class 'int'>, {'i': 104, 'a': 2147483647, 'p': 691418240, 'b': 691418240}), 16]
# mod b 10000
# [9105, defaultdict(<class 'int'>, {'i': 104, 'a': 2147483647, 'p': 691418240, 'b': 8240}), 17]
# snd b
# [8240, defaultdict(<class 'int'>, {'i': 104, 'a': 2147483647, 'p': 691418240, 'b': 8240}), 18]
# add i -1
# [8240, defaultdict(<class 'int'>, {'i': 103, 'a': 2147483647, 'p': 691418240, 'b': 8240}), 19]
# jgz i -9
# [8240, defaultdict(<class 'int'>, {'i': 103, 'a': 2147483647, 'p': 691418240, 'b': 8240}), 10]
# mul p 8505
# [8240, defaultdict(<class 'int'>, {'i': 103, 'a': 2147483647, 'p': 5880512131200, 'b': 8240}), 11]
# mod p a
# [8240, defaultdict(<class 'int'>, {'i': 103, 'a': 2147483647, 'p': 701905714, 'b': 8240}), 12]
# mul p 129749
# [8240, defaultdict(<class 'int'>, {'i': 103, 'a': 2147483647, 'p': 91071564485786, 'b': 8240}), 13]
# add p 12345
# [8240, defaultdict(<class 'int'>, {'i': 103, 'a': 2147483647, 'p': 91071564498131, 'b': 8240}), 14]
# mod p a
# [8240, defaultdict(<class 'int'>, {'i': 103, 'a': 2147483647, 'p': 1077996155, 'b': 8240}), 15]
# set b p
# [8240, defaultdict(<class 'int'>, {'i': 103, 'a': 2147483647, 'p': 1077996155, 'b': 1077996155}), 16]
# mod b 10000
# [8240, defaultdict(<class 'int'>, {'i': 103, 'a': 2147483647, 'p': 1077996155, 'b': 6155}), 17]
# snd b
# [6155, defaultdict(<class 'int'>, {'i': 103, 'a': 2147483647, 'p': 1077996155, 'b': 6155}), 18]
# add i -1
# [6155, defaultdict(<class 'int'>, {'i': 102, 'a': 2147483647, 'p': 1077996155, 'b': 6155}), 19]
# jgz i -9
# [6155, defaultdict(<class 'int'>, {'i': 102, 'a': 2147483647, 'p': 1077996155, 'b': 6155}), 10]
# mul p 8505
# [6155, defaultdict(<class 'int'>, {'i': 102, 'a': 2147483647, 'p': 9168357298275, 'b': 6155}), 11]
# mod p a
# [6155, defaultdict(<class 'int'>, {'i': 102, 'a': 2147483647, 'p': 749609232, 'b': 6155}), 12]
# mul p 129749
# [6155, defaultdict(<class 'int'>, {'i': 102, 'a': 2147483647, 'p': 97261048242768, 'b': 6155}), 13]
# add p 12345
# [6155, defaultdict(<class 'int'>, {'i': 102, 'a': 2147483647, 'p': 97261048255113, 'b': 6155}), 14]
# mod p a
# [6155, defaultdict(<class 'int'>, {'i': 102, 'a': 2147483647, 'p': 1513882483, 'b': 6155}), 15]
# set b p
# [6155, defaultdict(<class 'int'>, {'i': 102, 'a': 2147483647, 'p': 1513882483, 'b': 1513882483}), 16]
# mod b 10000
# [6155, defaultdict(<class 'int'>, {'i': 102, 'a': 2147483647, 'p': 1513882483, 'b': 2483}), 17]
# snd b
# [2483, defaultdict(<class 'int'>, {'i': 102, 'a': 2147483647, 'p': 1513882483, 'b': 2483}), 18]
# add i -1
# [2483, defaultdict(<class 'int'>, {'i': 101, 'a': 2147483647, 'p': 1513882483, 'b': 2483}), 19]
# jgz i -9
# [2483, defaultdict(<class 'int'>, {'i': 101, 'a': 2147483647, 'p': 1513882483, 'b': 2483}), 10]
# mul p 8505
# [2483, defaultdict(<class 'int'>, {'i': 101, 'a': 2147483647, 'p': 12875570517915, 'b': 2483}), 11]
# mod p a
# [2483, defaultdict(<class 'int'>, {'i': 101, 'a': 2147483647, 'p': 1406054150, 'b': 2483}), 12]
# mul p 129749
# [2483, defaultdict(<class 'int'>, {'i': 101, 'a': 2147483647, 'p': 182434119908350, 'b': 2483}), 13]
# add p 12345
# [2483, defaultdict(<class 'int'>, {'i': 101, 'a': 2147483647, 'p': 182434119920695, 'b': 2483}), 14]
# mod p a
# [2483, defaultdict(<class 'int'>, {'i': 101, 'a': 2147483647, 'p': 1089140751, 'b': 2483}), 15]
# set b p
# [2483, defaultdict(<class 'int'>, {'i': 101, 'a': 2147483647, 'p': 1089140751, 'b': 1089140751}), 16]
# mod b 10000
# [2483, defaultdict(<class 'int'>, {'i': 101, 'a': 2147483647, 'p': 1089140751, 'b': 751}), 17]
# snd b
# [751, defaultdict(<class 'int'>, {'i': 101, 'a': 2147483647, 'p': 1089140751, 'b': 751}), 18]
# add i -1
# [751, defaultdict(<class 'int'>, {'i': 100, 'a': 2147483647, 'p': 1089140751, 'b': 751}), 19]
# jgz i -9
# [751, defaultdict(<class 'int'>, {'i': 100, 'a': 2147483647, 'p': 1089140751, 'b': 751}), 10]
# mul p 8505
# [751, defaultdict(<class 'int'>, {'i': 100, 'a': 2147483647, 'p': 9263142087255, 'b': 751}), 11]
# mod p a
# [751, defaultdict(<class 'int'>, {'i': 100, 'a': 2147483647, 'p': 1045117744, 'b': 751}), 12]
# mul p 129749
# [751, defaultdict(<class 'int'>, {'i': 100, 'a': 2147483647, 'p': 135602982166256, 'b': 751}), 13]
# add p 12345
# [751, defaultdict(<class 'int'>, {'i': 100, 'a': 2147483647, 'p': 135602982178601, 'b': 751}), 14]
# mod p a
# [751, defaultdict(<class 'int'>, {'i': 100, 'a': 2147483647, 'p': 127288786, 'b': 751}), 15]
# set b p
# [751, defaultdict(<class 'int'>, {'i': 100, 'a': 2147483647, 'p': 127288786, 'b': 127288786}), 16]
# mod b 10000
# [751, defaultdict(<class 'int'>, {'i': 100, 'a': 2147483647, 'p': 127288786, 'b': 8786}), 17]
# snd b
# [8786, defaultdict(<class 'int'>, {'i': 100, 'a': 2147483647, 'p': 127288786, 'b': 8786}), 18]
# add i -1
# [8786, defaultdict(<class 'int'>, {'i': 99, 'a': 2147483647, 'p': 127288786, 'b': 8786}), 19]
# jgz i -9
# [8786, defaultdict(<class 'int'>, {'i': 99, 'a': 2147483647, 'p': 127288786, 'b': 8786}), 10]
# mul p 8505
# [8786, defaultdict(<class 'int'>, {'i': 99, 'a': 2147483647, 'p': 1082591124930, 'b': 8786}), 11]
# mod p a
# [8786, defaultdict(<class 'int'>, {'i': 99, 'a': 2147483647, 'p': 259366842, 'b': 8786}), 12]
# mul p 129749
# [8786, defaultdict(<class 'int'>, {'i': 99, 'a': 2147483647, 'p': 33652588382658, 'b': 8786}), 13]
# add p 12345
# [8786, defaultdict(<class 'int'>, {'i': 99, 'a': 2147483647, 'p': 33652588395003, 'b': 8786}), 14]
# mod p a
# [8786, defaultdict(<class 'int'>, {'i': 99, 'a': 2147483647, 'p': 1519646513, 'b': 8786}), 15]
# set b p
# [8786, defaultdict(<class 'int'>, {'i': 99, 'a': 2147483647, 'p': 1519646513, 'b': 1519646513}), 16]
# mod b 10000
# [8786, defaultdict(<class 'int'>, {'i': 99, 'a': 2147483647, 'p': 1519646513, 'b': 6513}), 17]
# snd b
# [6513, defaultdict(<class 'int'>, {'i': 99, 'a': 2147483647, 'p': 1519646513, 'b': 6513}), 18]
# add i -1
# [6513, defaultdict(<class 'int'>, {'i': 98, 'a': 2147483647, 'p': 1519646513, 'b': 6513}), 19]
# jgz i -9
# [6513, defaultdict(<class 'int'>, {'i': 98, 'a': 2147483647, 'p': 1519646513, 'b': 6513}), 10]
# mul p 8505
# [6513, defaultdict(<class 'int'>, {'i': 98, 'a': 2147483647, 'p': 12924593593065, 'b': 6513}), 11]
# mod p a
# [6513, defaultdict(<class 'int'>, {'i': 98, 'a': 2147483647, 'p': 1037005419, 'b': 6513}), 12]
# mul p 129749
# [6513, defaultdict(<class 'int'>, {'i': 98, 'a': 2147483647, 'p': 134550416109831, 'b': 6513}), 13]
# add p 12345
# [6513, defaultdict(<class 'int'>, {'i': 98, 'a': 2147483647, 'p': 134550416122176, 'b': 6513}), 14]
# mod p a
# [6513, defaultdict(<class 'int'>, {'i': 98, 'a': 2147483647, 'p': 1975703038, 'b': 6513}), 15]
# set b p
# [6513, defaultdict(<class 'int'>, {'i': 98, 'a': 2147483647, 'p': 1975703038, 'b': 1975703038}), 16]
# mod b 10000
# [6513, defaultdict(<class 'int'>, {'i': 98, 'a': 2147483647, 'p': 1975703038, 'b': 3038}), 17]
# snd b
# [3038, defaultdict(<class 'int'>, {'i': 98, 'a': 2147483647, 'p': 1975703038, 'b': 3038}), 18]
# add i -1
# [3038, defaultdict(<class 'int'>, {'i': 97, 'a': 2147483647, 'p': 1975703038, 'b': 3038}), 19]
# jgz i -9
# [3038, defaultdict(<class 'int'>, {'i': 97, 'a': 2147483647, 'p': 1975703038, 'b': 3038}), 10]
# mul p 8505
# [3038, defaultdict(<class 'int'>, {'i': 97, 'a': 2147483647, 'p': 16803354338190, 'b': 3038}), 11]
# mod p a
# [3038, defaultdict(<class 'int'>, {'i': 97, 'a': 2147483647, 'p': 1442284062, 'b': 3038}), 12]
# mul p 129749
# [3038, defaultdict(<class 'int'>, {'i': 97, 'a': 2147483647, 'p': 187134914760438, 'b': 3038}), 13]
# add p 12345
# [3038, defaultdict(<class 'int'>, {'i': 97, 'a': 2147483647, 'p': 187134914772783, 'b': 3038}), 14]
# mod p a
# [3038, defaultdict(<class 'int'>, {'i': 97, 'a': 2147483647, 'p': 1042289556, 'b': 3038}), 15]
# set b p
# [3038, defaultdict(<class 'int'>, {'i': 97, 'a': 2147483647, 'p': 1042289556, 'b': 1042289556}), 16]
# mod b 10000
# [3038, defaultdict(<class 'int'>, {'i': 97, 'a': 2147483647, 'p': 1042289556, 'b': 9556}), 17]
# snd b
# [9556, defaultdict(<class 'int'>, {'i': 97, 'a': 2147483647, 'p': 1042289556, 'b': 9556}), 18]
# add i -1
# [9556, defaultdict(<class 'int'>, {'i': 96, 'a': 2147483647, 'p': 1042289556, 'b': 9556}), 19]
# jgz i -9
# [9556, defaultdict(<class 'int'>, {'i': 96, 'a': 2147483647, 'p': 1042289556, 'b': 9556}), 10]
# mul p 8505
# [9556, defaultdict(<class 'int'>, {'i': 96, 'a': 2147483647, 'p': 8864672673780, 'b': 9556}), 11]
# mod p a
# [9556, defaultdict(<class 'int'>, {'i': 96, 'a': 2147483647, 'p': 2007662611, 'b': 9556}), 12]
# mul p 129749
# [9556, defaultdict(<class 'int'>, {'i': 96, 'a': 2147483647, 'p': 260492216114639, 'b': 9556}), 13]
# add p 12345
# [9556, defaultdict(<class 'int'>, {'i': 96, 'a': 2147483647, 'p': 260492216126984, 'b': 9556}), 14]
# mod p a
# [9556, defaultdict(<class 'int'>, {'i': 96, 'a': 2147483647, 'p': 302262237, 'b': 9556}), 15]
# set b p
# [9556, defaultdict(<class 'int'>, {'i': 96, 'a': 2147483647, 'p': 302262237, 'b': 302262237}), 16]
# mod b 10000
# [9556, defaultdict(<class 'int'>, {'i': 96, 'a': 2147483647, 'p': 302262237, 'b': 2237}), 17]
# snd b
# [2237, defaultdict(<class 'int'>, {'i': 96, 'a': 2147483647, 'p': 302262237, 'b': 2237}), 18]
# add i -1
# [2237, defaultdict(<class 'int'>, {'i': 95, 'a': 2147483647, 'p': 302262237, 'b': 2237}), 19]
# jgz i -9
# [2237, defaultdict(<class 'int'>, {'i': 95, 'a': 2147483647, 'p': 302262237, 'b': 2237}), 10]
# mul p 8505
# [2237, defaultdict(<class 'int'>, {'i': 95, 'a': 2147483647, 'p': 2570740325685, 'b': 2237}), 11]
# mod p a
# [2237, defaultdict(<class 'int'>, {'i': 95, 'a': 2147483647, 'p': 202400226, 'b': 2237}), 12]
# mul p 129749
# [2237, defaultdict(<class 'int'>, {'i': 95, 'a': 2147483647, 'p': 26261226923274, 'b': 2237}), 13]
# add p 12345
# [2237, defaultdict(<class 'int'>, {'i': 95, 'a': 2147483647, 'p': 26261226935619, 'b': 2237}), 14]
# mod p a
# [2237, defaultdict(<class 'int'>, {'i': 95, 'a': 2147483647, 'p': 1796900103, 'b': 2237}), 15]
# set b p
# [2237, defaultdict(<class 'int'>, {'i': 95, 'a': 2147483647, 'p': 1796900103, 'b': 1796900103}), 16]
# mod b 10000
# [2237, defaultdict(<class 'int'>, {'i': 95, 'a': 2147483647, 'p': 1796900103, 'b': 103}), 17]
# snd b
# [103, defaultdict(<class 'int'>, {'i': 95, 'a': 2147483647, 'p': 1796900103, 'b': 103}), 18]
# add i -1
# [103, defaultdict(<class 'int'>, {'i': 94, 'a': 2147483647, 'p': 1796900103, 'b': 103}), 19]
# jgz i -9
# [103, defaultdict(<class 'int'>, {'i': 94, 'a': 2147483647, 'p': 1796900103, 'b': 103}), 10]
# mul p 8505
# [103, defaultdict(<class 'int'>, {'i': 94, 'a': 2147483647, 'p': 15282635376015, 'b': 103}), 11]
# mod p a
# [103, defaultdict(<class 'int'>, {'i': 94, 'a': 2147483647, 'p': 1141743963, 'b': 103}), 12]
# mul p 129749
# [103, defaultdict(<class 'int'>, {'i': 94, 'a': 2147483647, 'p': 148140137455287, 'b': 103}), 13]
# add p 12345
# [103, defaultdict(<class 'int'>, {'i': 94, 'a': 2147483647, 'p': 148140137467632, 'b': 103}), 14]
# mod p a
# [103, defaultdict(<class 'int'>, {'i': 94, 'a': 2147483647, 'p': 273046631, 'b': 103}), 15]
# set b p
# [103, defaultdict(<class 'int'>, {'i': 94, 'a': 2147483647, 'p': 273046631, 'b': 273046631}), 16]
# mod b 10000
# [103, defaultdict(<class 'int'>, {'i': 94, 'a': 2147483647, 'p': 273046631, 'b': 6631}), 17]
# snd b
# [6631, defaultdict(<class 'int'>, {'i': 94, 'a': 2147483647, 'p': 273046631, 'b': 6631}), 18]
# add i -1
# [6631, defaultdict(<class 'int'>, {'i': 93, 'a': 2147483647, 'p': 273046631, 'b': 6631}), 19]
# jgz i -9
# [6631, defaultdict(<class 'int'>, {'i': 93, 'a': 2147483647, 'p': 273046631, 'b': 6631}), 10]
# mul p 8505
# [6631, defaultdict(<class 'int'>, {'i': 93, 'a': 2147483647, 'p': 2322261596655, 'b': 6631}), 11]
# mod p a
# [6631, defaultdict(<class 'int'>, {'i': 93, 'a': 2147483647, 'p': 831774248, 'b': 6631}), 12]
# mul p 129749
# [6631, defaultdict(<class 'int'>, {'i': 93, 'a': 2147483647, 'p': 107921876903752, 'b': 6631}), 13]
# add p 12345
# [6631, defaultdict(<class 'int'>, {'i': 93, 'a': 2147483647, 'p': 107921876916097, 'b': 6631}), 14]
# mod p a
# [6631, defaultdict(<class 'int'>, {'i': 93, 'a': 2147483647, 'p': 86236112, 'b': 6631}), 15]
# set b p
# [6631, defaultdict(<class 'int'>, {'i': 93, 'a': 2147483647, 'p': 86236112, 'b': 86236112}), 16]
# mod b 10000
# [6631, defaultdict(<class 'int'>, {'i': 93, 'a': 2147483647, 'p': 86236112, 'b': 6112}), 17]
# snd b
# [6112, defaultdict(<class 'int'>, {'i': 93, 'a': 2147483647, 'p': 86236112, 'b': 6112}), 18]
# add i -1
# [6112, defaultdict(<class 'int'>, {'i': 92, 'a': 2147483647, 'p': 86236112, 'b': 6112}), 19]
# jgz i -9
# [6112, defaultdict(<class 'int'>, {'i': 92, 'a': 2147483647, 'p': 86236112, 'b': 6112}), 10]
# mul p 8505
# [6112, defaultdict(<class 'int'>, {'i': 92, 'a': 2147483647, 'p': 733438132560, 'b': 6112}), 11]
# mod p a
# [6112, defaultdict(<class 'int'>, {'i': 92, 'a': 2147483647, 'p': 1146208933, 'b': 6112}), 12]
# mul p 129749
# [6112, defaultdict(<class 'int'>, {'i': 92, 'a': 2147483647, 'p': 148719462847817, 'b': 6112}), 13]
# add p 12345
# [6112, defaultdict(<class 'int'>, {'i': 92, 'a': 2147483647, 'p': 148719462860162, 'b': 6112}), 14]
# mod p a
# [6112, defaultdict(<class 'int'>, {'i': 92, 'a': 2147483647, 'p': 1925338118, 'b': 6112}), 15]
# set b p
# [6112, defaultdict(<class 'int'>, {'i': 92, 'a': 2147483647, 'p': 1925338118, 'b': 1925338118}), 16]
# mod b 10000
# [6112, defaultdict(<class 'int'>, {'i': 92, 'a': 2147483647, 'p': 1925338118, 'b': 8118}), 17]
# snd b
# [8118, defaultdict(<class 'int'>, {'i': 92, 'a': 2147483647, 'p': 1925338118, 'b': 8118}), 18]
# add i -1
# [8118, defaultdict(<class 'int'>, {'i': 91, 'a': 2147483647, 'p': 1925338118, 'b': 8118}), 19]
# jgz i -9
# [8118, defaultdict(<class 'int'>, {'i': 91, 'a': 2147483647, 'p': 1925338118, 'b': 8118}), 10]
# mul p 8505
# [8118, defaultdict(<class 'int'>, {'i': 91, 'a': 2147483647, 'p': 16375000693590, 'b': 8118}), 11]
# mod p a
# [8118, defaultdict(<class 'int'>, {'i': 91, 'a': 2147483647, 'p': 437885215, 'b': 8118}), 12]
# mul p 129749
# [8118, defaultdict(<class 'int'>, {'i': 91, 'a': 2147483647, 'p': 56815168761035, 'b': 8118}), 13]
# add p 12345
# [8118, defaultdict(<class 'int'>, {'i': 91, 'a': 2147483647, 'p': 56815168773380, 'b': 8118}), 14]
# mod p a
# [8118, defaultdict(<class 'int'>, {'i': 91, 'a': 2147483647, 'p': 1341408348, 'b': 8118}), 15]
# set b p
# [8118, defaultdict(<class 'int'>, {'i': 91, 'a': 2147483647, 'p': 1341408348, 'b': 1341408348}), 16]
# mod b 10000
# [8118, defaultdict(<class 'int'>, {'i': 91, 'a': 2147483647, 'p': 1341408348, 'b': 8348}), 17]
# snd b
# [8348, defaultdict(<class 'int'>, {'i': 91, 'a': 2147483647, 'p': 1341408348, 'b': 8348}), 18]
# add i -1
# [8348, defaultdict(<class 'int'>, {'i': 90, 'a': 2147483647, 'p': 1341408348, 'b': 8348}), 19]
# jgz i -9
# [8348, defaultdict(<class 'int'>, {'i': 90, 'a': 2147483647, 'p': 1341408348, 'b': 8348}), 10]
# mul p 8505
# [8348, defaultdict(<class 'int'>, {'i': 90, 'a': 2147483647, 'p': 11408677999740, 'b': 8348}), 11]
# mod p a
# [8348, defaultdict(<class 'int'>, {'i': 90, 'a': 2147483647, 'p': 1244866876, 'b': 8348}), 12]
# mul p 129749
# [8348, defaultdict(<class 'int'>, {'i': 90, 'a': 2147483647, 'p': 161520232294124, 'b': 8348}), 13]
# add p 12345
# [8348, defaultdict(<class 'int'>, {'i': 90, 'a': 2147483647, 'p': 161520232306469, 'b': 8348}), 14]
# mod p a
# [8348, defaultdict(<class 'int'>, {'i': 90, 'a': 2147483647, 'p': 1544764658, 'b': 8348}), 15]
# set b p
# [8348, defaultdict(<class 'int'>, {'i': 90, 'a': 2147483647, 'p': 1544764658, 'b': 1544764658}), 16]
# mod b 10000
# [8348, defaultdict(<class 'int'>, {'i': 90, 'a': 2147483647, 'p': 1544764658, 'b': 4658}), 17]
# snd b
# [4658, defaultdict(<class 'int'>, {'i': 90, 'a': 2147483647, 'p': 1544764658, 'b': 4658}), 18]
# add i -1
# [4658, defaultdict(<class 'int'>, {'i': 89, 'a': 2147483647, 'p': 1544764658, 'b': 4658}), 19]
# jgz i -9
# [4658, defaultdict(<class 'int'>, {'i': 89, 'a': 2147483647, 'p': 1544764658, 'b': 4658}), 10]
# mul p 8505
# ...
# mod p a
# [729, defaultdict(<class 'int'>, {'i': 15, 'a': 2147483647, 'p': 2040960844, 'b': 729}), 12]
# mul p 129749
# [729, defaultdict(<class 'int'>, {'i': 15, 'a': 2147483647, 'p': 264812628548156, 'b': 729}), 13]
# add p 12345
# [729, defaultdict(<class 'int'>, {'i': 15, 'a': 2147483647, 'p': 264812628560501, 'b': 729}), 14]
# mod p a
# [729, defaultdict(<class 'int'>, {'i': 15, 'a': 2147483647, 'p': 2125081637, 'b': 729}), 15]
# set b p
# [729, defaultdict(<class 'int'>, {'i': 15, 'a': 2147483647, 'p': 2125081637, 'b': 2125081637}), 16]
# mod b 10000
# [729, defaultdict(<class 'int'>, {'i': 15, 'a': 2147483647, 'p': 2125081637, 'b': 1637}), 17]
# snd b
# [1637, defaultdict(<class 'int'>, {'i': 15, 'a': 2147483647, 'p': 2125081637, 'b': 1637}), 18]
# add i -1
# [1637, defaultdict(<class 'int'>, {'i': 14, 'a': 2147483647, 'p': 2125081637, 'b': 1637}), 19]
# jgz i -9
# [1637, defaultdict(<class 'int'>, {'i': 14, 'a': 2147483647, 'p': 2125081637, 'b': 1637}), 10]
# mul p 8505
# [1637, defaultdict(<class 'int'>, {'i': 14, 'a': 2147483647, 'p': 18073819322685, 'b': 1637}), 11]
# mod p a
# [1637, defaultdict(<class 'int'>, {'i': 14, 'a': 2147483647, 'p': 596949533, 'b': 1637}), 12]
# mul p 129749
# [1637, defaultdict(<class 'int'>, {'i': 14, 'a': 2147483647, 'p': 77453604957217, 'b': 1637}), 13]
# add p 12345
# [1637, defaultdict(<class 'int'>, {'i': 14, 'a': 2147483647, 'p': 77453604969562, 'b': 1637}), 14]
# mod p a
# [1637, defaultdict(<class 'int'>, {'i': 14, 'a': 2147483647, 'p': 312273213, 'b': 1637}), 15]
# set b p
# [1637, defaultdict(<class 'int'>, {'i': 14, 'a': 2147483647, 'p': 312273213, 'b': 312273213}), 16]
# mod b 10000
# [1637, defaultdict(<class 'int'>, {'i': 14, 'a': 2147483647, 'p': 312273213, 'b': 3213}), 17]
# snd b
# [3213, defaultdict(<class 'int'>, {'i': 14, 'a': 2147483647, 'p': 312273213, 'b': 3213}), 18]
# add i -1
# [3213, defaultdict(<class 'int'>, {'i': 13, 'a': 2147483647, 'p': 312273213, 'b': 3213}), 19]
# jgz i -9
# [3213, defaultdict(<class 'int'>, {'i': 13, 'a': 2147483647, 'p': 312273213, 'b': 3213}), 10]
# mul p 8505
# [3213, defaultdict(<class 'int'>, {'i': 13, 'a': 2147483647, 'p': 2655883676565, 'b': 3213}), 11]
# mod p a
# [3213, defaultdict(<class 'int'>, {'i': 13, 'a': 2147483647, 'p': 1593888873, 'b': 3213}), 12]
# mul p 129749
# [3213, defaultdict(<class 'int'>, {'i': 13, 'a': 2147483647, 'p': 206805487382877, 'b': 3213}), 13]
# add p 12345
# [3213, defaultdict(<class 'int'>, {'i': 13, 'a': 2147483647, 'p': 206805487395222, 'b': 3213}), 14]
# mod p a
# [3213, defaultdict(<class 'int'>, {'i': 13, 'a': 2147483647, 'p': 664705475, 'b': 3213}), 15]
# set b p
# [3213, defaultdict(<class 'int'>, {'i': 13, 'a': 2147483647, 'p': 664705475, 'b': 664705475}), 16]
# mod b 10000
# [3213, defaultdict(<class 'int'>, {'i': 13, 'a': 2147483647, 'p': 664705475, 'b': 5475}), 17]
# snd b
# [5475, defaultdict(<class 'int'>, {'i': 13, 'a': 2147483647, 'p': 664705475, 'b': 5475}), 18]
# add i -1
# [5475, defaultdict(<class 'int'>, {'i': 12, 'a': 2147483647, 'p': 664705475, 'b': 5475}), 19]
# jgz i -9
# [5475, defaultdict(<class 'int'>, {'i': 12, 'a': 2147483647, 'p': 664705475, 'b': 5475}), 10]
# mul p 8505
# [5475, defaultdict(<class 'int'>, {'i': 12, 'a': 2147483647, 'p': 5653320064875, 'b': 5475}), 11]
# mod p a
# [5475, defaultdict(<class 'int'>, {'i': 12, 'a': 2147483647, 'p': 1143105971, 'b': 5475}), 12]
# mul p 129749
# [5475, defaultdict(<class 'int'>, {'i': 12, 'a': 2147483647, 'p': 148316856631279, 'b': 5475}), 13]
# add p 12345
# [5475, defaultdict(<class 'int'>, {'i': 12, 'a': 2147483647, 'p': 148316856643624, 'b': 5475}), 14]
# mod p a
# [5475, defaultdict(<class 'int'>, {'i': 12, 'a': 2147483647, 'p': 898563569, 'b': 5475}), 15]
# set b p
# [5475, defaultdict(<class 'int'>, {'i': 12, 'a': 2147483647, 'p': 898563569, 'b': 898563569}), 16]
# mod b 10000
# [5475, defaultdict(<class 'int'>, {'i': 12, 'a': 2147483647, 'p': 898563569, 'b': 3569}), 17]
# snd b
# [3569, defaultdict(<class 'int'>, {'i': 12, 'a': 2147483647, 'p': 898563569, 'b': 3569}), 18]
# add i -1
# [3569, defaultdict(<class 'int'>, {'i': 11, 'a': 2147483647, 'p': 898563569, 'b': 3569}), 19]
# jgz i -9
# [3569, defaultdict(<class 'int'>, {'i': 11, 'a': 2147483647, 'p': 898563569, 'b': 3569}), 10]
# mul p 8505
# [3569, defaultdict(<class 'int'>, {'i': 11, 'a': 2147483647, 'p': 7642283154345, 'b': 3569}), 11]
# mod p a
# [3569, defaultdict(<class 'int'>, {'i': 11, 'a': 2147483647, 'p': 1536338319, 'b': 3569}), 12]
# mul p 129749
# [3569, defaultdict(<class 'int'>, {'i': 11, 'a': 2147483647, 'p': 199338360551931, 'b': 3569}), 13]
# add p 12345
# [3569, defaultdict(<class 'int'>, {'i': 11, 'a': 2147483647, 'p': 199338360564276, 'b': 3569}), 14]
# mod p a
# [3569, defaultdict(<class 'int'>, {'i': 11, 'a': 2147483647, 'p': 338515148, 'b': 3569}), 15]
# set b p
# [3569, defaultdict(<class 'int'>, {'i': 11, 'a': 2147483647, 'p': 338515148, 'b': 338515148}), 16]
# mod b 10000
# [3569, defaultdict(<class 'int'>, {'i': 11, 'a': 2147483647, 'p': 338515148, 'b': 5148}), 17]
# snd b
# [5148, defaultdict(<class 'int'>, {'i': 11, 'a': 2147483647, 'p': 338515148, 'b': 5148}), 18]
# add i -1
# [5148, defaultdict(<class 'int'>, {'i': 10, 'a': 2147483647, 'p': 338515148, 'b': 5148}), 19]
# jgz i -9
# [5148, defaultdict(<class 'int'>, {'i': 10, 'a': 2147483647, 'p': 338515148, 'b': 5148}), 10]
# mul p 8505
# [5148, defaultdict(<class 'int'>, {'i': 10, 'a': 2147483647, 'p': 2879071333740, 'b': 5148}), 11]
# mod p a
# [5148, defaultdict(<class 'int'>, {'i': 10, 'a': 2147483647, 'p': 1443246760, 'b': 5148}), 12]
# mul p 129749
# [5148, defaultdict(<class 'int'>, {'i': 10, 'a': 2147483647, 'p': 187259823863240, 'b': 5148}), 13]
# add p 12345
# [5148, defaultdict(<class 'int'>, {'i': 10, 'a': 2147483647, 'p': 187259823875585, 'b': 5148}), 14]
# mod p a
# [5148, defaultdict(<class 'int'>, {'i': 10, 'a': 2147483647, 'p': 1397340832, 'b': 5148}), 15]
# set b p
# [5148, defaultdict(<class 'int'>, {'i': 10, 'a': 2147483647, 'p': 1397340832, 'b': 1397340832}), 16]
# mod b 10000
# [5148, defaultdict(<class 'int'>, {'i': 10, 'a': 2147483647, 'p': 1397340832, 'b': 832}), 17]
# snd b
# [832, defaultdict(<class 'int'>, {'i': 10, 'a': 2147483647, 'p': 1397340832, 'b': 832}), 18]
# add i -1
# [832, defaultdict(<class 'int'>, {'i': 9, 'a': 2147483647, 'p': 1397340832, 'b': 832}), 19]
# jgz i -9
# [832, defaultdict(<class 'int'>, {'i': 9, 'a': 2147483647, 'p': 1397340832, 'b': 832}), 10]
# mul p 8505
# [832, defaultdict(<class 'int'>, {'i': 9, 'a': 2147483647, 'p': 11884383776160, 'b': 832}), 11]
# mod p a
# [832, defaultdict(<class 'int'>, {'i': 9, 'a': 2147483647, 'p': 209273662, 'b': 832}), 12]
# mul p 129749
# [832, defaultdict(<class 'int'>, {'i': 9, 'a': 2147483647, 'p': 27153048370838, 'b': 832}), 13]
# add p 12345
# [832, defaultdict(<class 'int'>, {'i': 9, 'a': 2147483647, 'p': 27153048383183, 'b': 832}), 14]
# mod p a
# [832, defaultdict(<class 'int'>, {'i': 9, 'a': 2147483647, 'p': 265150515, 'b': 832}), 15]
# set b p
# [832, defaultdict(<class 'int'>, {'i': 9, 'a': 2147483647, 'p': 265150515, 'b': 265150515}), 16]
# mod b 10000
# [832, defaultdict(<class 'int'>, {'i': 9, 'a': 2147483647, 'p': 265150515, 'b': 515}), 17]
# snd b
# [515, defaultdict(<class 'int'>, {'i': 9, 'a': 2147483647, 'p': 265150515, 'b': 515}), 18]
# add i -1
# [515, defaultdict(<class 'int'>, {'i': 8, 'a': 2147483647, 'p': 265150515, 'b': 515}), 19]
# jgz i -9
# [515, defaultdict(<class 'int'>, {'i': 8, 'a': 2147483647, 'p': 265150515, 'b': 515}), 10]
# mul p 8505
# [515, defaultdict(<class 'int'>, {'i': 8, 'a': 2147483647, 'p': 2255105130075, 'b': 515}), 11]
# mod p a
# [515, defaultdict(<class 'int'>, {'i': 8, 'a': 2147483647, 'p': 247300725, 'b': 515}), 12]
# mul p 129749
# [515, defaultdict(<class 'int'>, {'i': 8, 'a': 2147483647, 'p': 32087021768025, 'b': 515}), 13]
# add p 12345
# [515, defaultdict(<class 'int'>, {'i': 8, 'a': 2147483647, 'p': 32087021780370, 'b': 515}), 14]
# mod p a
# [515, defaultdict(<class 'int'>, {'i': 8, 'a': 2147483647, 'p': 1468610543, 'b': 515}), 15]
# set b p
# [515, defaultdict(<class 'int'>, {'i': 8, 'a': 2147483647, 'p': 1468610543, 'b': 1468610543}), 16]
# mod b 10000
# [515, defaultdict(<class 'int'>, {'i': 8, 'a': 2147483647, 'p': 1468610543, 'b': 543}), 17]
# snd b
# [543, defaultdict(<class 'int'>, {'i': 8, 'a': 2147483647, 'p': 1468610543, 'b': 543}), 18]
# add i -1
# [543, defaultdict(<class 'int'>, {'i': 7, 'a': 2147483647, 'p': 1468610543, 'b': 543}), 19]
# jgz i -9
# [543, defaultdict(<class 'int'>, {'i': 7, 'a': 2147483647, 'p': 1468610543, 'b': 543}), 10]
# mul p 8505
# [543, defaultdict(<class 'int'>, {'i': 7, 'a': 2147483647, 'p': 12490532668215, 'b': 543}), 11]
# mod p a
# [543, defaultdict(<class 'int'>, {'i': 7, 'a': 2147483647, 'p': 767777263, 'b': 543}), 12]
# mul p 129749
# [543, defaultdict(<class 'int'>, {'i': 7, 'a': 2147483647, 'p': 99618332096987, 'b': 543}), 13]
# add p 12345
# [543, defaultdict(<class 'int'>, {'i': 7, 'a': 2147483647, 'p': 99618332109332, 'b': 543}), 14]
# mod p a
# [543, defaultdict(<class 'int'>, {'i': 7, 'a': 2147483647, 'p': 860692296, 'b': 543}), 15]
# set b p
# [543, defaultdict(<class 'int'>, {'i': 7, 'a': 2147483647, 'p': 860692296, 'b': 860692296}), 16]
# mod b 10000
# [543, defaultdict(<class 'int'>, {'i': 7, 'a': 2147483647, 'p': 860692296, 'b': 2296}), 17]
# snd b
# [2296, defaultdict(<class 'int'>, {'i': 7, 'a': 2147483647, 'p': 860692296, 'b': 2296}), 18]
# add i -1
# [2296, defaultdict(<class 'int'>, {'i': 6, 'a': 2147483647, 'p': 860692296, 'b': 2296}), 19]
# jgz i -9
# [2296, defaultdict(<class 'int'>, {'i': 6, 'a': 2147483647, 'p': 860692296, 'b': 2296}), 10]
# mul p 8505
# [2296, defaultdict(<class 'int'>, {'i': 6, 'a': 2147483647, 'p': 7320187977480, 'b': 2296}), 11]
# mod p a
# [2296, defaultdict(<class 'int'>, {'i': 6, 'a': 2147483647, 'p': 1563708504, 'b': 2296}), 12]
# mul p 129749
# [2296, defaultdict(<class 'int'>, {'i': 6, 'a': 2147483647, 'p': 202889614685496, 'b': 2296}), 13]
# add p 12345
# [2296, defaultdict(<class 'int'>, {'i': 6, 'a': 2147483647, 'p': 202889614697841, 'b': 2296}), 14]
# mod p a
# [2296, defaultdict(<class 'int'>, {'i': 6, 'a': 2147483647, 'p': 1802180222, 'b': 2296}), 15]
# set b p
# [2296, defaultdict(<class 'int'>, {'i': 6, 'a': 2147483647, 'p': 1802180222, 'b': 1802180222}), 16]
# mod b 10000
# [2296, defaultdict(<class 'int'>, {'i': 6, 'a': 2147483647, 'p': 1802180222, 'b': 222}), 17]
# snd b
# [222, defaultdict(<class 'int'>, {'i': 6, 'a': 2147483647, 'p': 1802180222, 'b': 222}), 18]
# add i -1
# [222, defaultdict(<class 'int'>, {'i': 5, 'a': 2147483647, 'p': 1802180222, 'b': 222}), 19]
# jgz i -9
# [222, defaultdict(<class 'int'>, {'i': 5, 'a': 2147483647, 'p': 1802180222, 'b': 222}), 10]
# mul p 8505
# [222, defaultdict(<class 'int'>, {'i': 5, 'a': 2147483647, 'p': 15327542788110, 'b': 222}), 11]
# mod p a
# [222, defaultdict(<class 'int'>, {'i': 5, 'a': 2147483647, 'p': 951999471, 'b': 222}), 12]
# mul p 129749
# [222, defaultdict(<class 'int'>, {'i': 5, 'a': 2147483647, 'p': 123520979362779, 'b': 222}), 13]
# add p 12345
# [222, defaultdict(<class 'int'>, {'i': 5, 'a': 2147483647, 'p': 123520979375124, 'b': 222}), 14]
# mod p a
# [222, defaultdict(<class 'int'>, {'i': 5, 'a': 2147483647, 'p': 2014966978, 'b': 222}), 15]
# set b p
# [222, defaultdict(<class 'int'>, {'i': 5, 'a': 2147483647, 'p': 2014966978, 'b': 2014966978}), 16]
# mod b 10000
# [222, defaultdict(<class 'int'>, {'i': 5, 'a': 2147483647, 'p': 2014966978, 'b': 6978}), 17]
# snd b
# [6978, defaultdict(<class 'int'>, {'i': 5, 'a': 2147483647, 'p': 2014966978, 'b': 6978}), 18]
# add i -1
# [6978, defaultdict(<class 'int'>, {'i': 4, 'a': 2147483647, 'p': 2014966978, 'b': 6978}), 19]
# jgz i -9
# [6978, defaultdict(<class 'int'>, {'i': 4, 'a': 2147483647, 'p': 2014966978, 'b': 6978}), 10]
# mul p 8505
# [6978, defaultdict(<class 'int'>, {'i': 4, 'a': 2147483647, 'p': 17137294147890, 'b': 6978}), 11]
# mod p a
# [6978, defaultdict(<class 'int'>, {'i': 4, 'a': 2147483647, 'p': 374644830, 'b': 6978}), 12]
# mul p 129749
# [6978, defaultdict(<class 'int'>, {'i': 4, 'a': 2147483647, 'p': 48609792047670, 'b': 6978}), 13]
# add p 12345
# [6978, defaultdict(<class 'int'>, {'i': 4, 'a': 2147483647, 'p': 48609792060015, 'b': 6978}), 14]
# mod p a
# [6978, defaultdict(<class 'int'>, {'i': 4, 'a': 2147483647, 'p': 1499710170, 'b': 6978}), 15]
# set b p
# [6978, defaultdict(<class 'int'>, {'i': 4, 'a': 2147483647, 'p': 1499710170, 'b': 1499710170}), 16]
# mod b 10000
# [6978, defaultdict(<class 'int'>, {'i': 4, 'a': 2147483647, 'p': 1499710170, 'b': 170}), 17]
# snd b
# [170, defaultdict(<class 'int'>, {'i': 4, 'a': 2147483647, 'p': 1499710170, 'b': 170}), 18]
# add i -1
# [170, defaultdict(<class 'int'>, {'i': 3, 'a': 2147483647, 'p': 1499710170, 'b': 170}), 19]
# jgz i -9
# [170, defaultdict(<class 'int'>, {'i': 3, 'a': 2147483647, 'p': 1499710170, 'b': 170}), 10]
# mul p 8505
# [170, defaultdict(<class 'int'>, {'i': 3, 'a': 2147483647, 'p': 12755034995850, 'b': 170}), 11]
# mod p a
# [170, defaultdict(<class 'int'>, {'i': 3, 'a': 2147483647, 'p': 1129616317, 'b': 170}), 12]
# mul p 129749
# [170, defaultdict(<class 'int'>, {'i': 3, 'a': 2147483647, 'p': 146566587514433, 'b': 170}), 13]
# add p 12345
# [170, defaultdict(<class 'int'>, {'i': 3, 'a': 2147483647, 'p': 146566587526778, 'b': 170}), 14]
# mod p a
# [170, defaultdict(<class 'int'>, {'i': 3, 'a': 2147483647, 'p': 828619028, 'b': 170}), 15]
# set b p
# [170, defaultdict(<class 'int'>, {'i': 3, 'a': 2147483647, 'p': 828619028, 'b': 828619028}), 16]
# mod b 10000
# [170, defaultdict(<class 'int'>, {'i': 3, 'a': 2147483647, 'p': 828619028, 'b': 9028}), 17]
# snd b
# [9028, defaultdict(<class 'int'>, {'i': 3, 'a': 2147483647, 'p': 828619028, 'b': 9028}), 18]
# add i -1
# [9028, defaultdict(<class 'int'>, {'i': 2, 'a': 2147483647, 'p': 828619028, 'b': 9028}), 19]
# jgz i -9
# [9028, defaultdict(<class 'int'>, {'i': 2, 'a': 2147483647, 'p': 828619028, 'b': 9028}), 10]
# mul p 8505
# [9028, defaultdict(<class 'int'>, {'i': 2, 'a': 2147483647, 'p': 7047404833140, 'b': 9028}), 11]
# mod p a
# [9028, defaultdict(<class 'int'>, {'i': 2, 'a': 2147483647, 'p': 1510987333, 'b': 9028}), 12]
# mul p 129749
# [9028, defaultdict(<class 'int'>, {'i': 2, 'a': 2147483647, 'p': 196049095469417, 'b': 9028}), 13]
# add p 12345
# [9028, defaultdict(<class 'int'>, {'i': 2, 'a': 2147483647, 'p': 196049095481762, 'b': 9028}), 14]
# mod p a
# [9028, defaultdict(<class 'int'>, {'i': 2, 'a': 2147483647, 'p': 1018379838, 'b': 9028}), 15]
# set b p
# [9028, defaultdict(<class 'int'>, {'i': 2, 'a': 2147483647, 'p': 1018379838, 'b': 1018379838}), 16]
# mod b 10000
# [9028, defaultdict(<class 'int'>, {'i': 2, 'a': 2147483647, 'p': 1018379838, 'b': 9838}), 17]
# snd b
# [9838, defaultdict(<class 'int'>, {'i': 2, 'a': 2147483647, 'p': 1018379838, 'b': 9838}), 18]
# add i -1
# [9838, defaultdict(<class 'int'>, {'i': 1, 'a': 2147483647, 'p': 1018379838, 'b': 9838}), 19]
# jgz i -9
# [9838, defaultdict(<class 'int'>, {'i': 1, 'a': 2147483647, 'p': 1018379838, 'b': 9838}), 10]
# mul p 8505
# [9838, defaultdict(<class 'int'>, {'i': 1, 'a': 2147483647, 'p': 8661320522190, 'b': 9838}), 11]
# mod p a
# [9838, defaultdict(<class 'int'>, {'i': 1, 'a': 2147483647, 'p': 518973839, 'b': 9838}), 12]
# mul p 129749
# [9838, defaultdict(<class 'int'>, {'i': 1, 'a': 2147483647, 'p': 67336336636411, 'b': 9838}), 13]
# add p 12345
# [9838, defaultdict(<class 'int'>, {'i': 1, 'a': 2147483647, 'p': 67336336648756, 'b': 9838}), 14]
# mod p a
# [9838, defaultdict(<class 'int'>, {'i': 1, 'a': 2147483647, 'p': 1986897071, 'b': 9838}), 15]
# set b p
# [9838, defaultdict(<class 'int'>, {'i': 1, 'a': 2147483647, 'p': 1986897071, 'b': 1986897071}), 16]
# mod b 10000
# [9838, defaultdict(<class 'int'>, {'i': 1, 'a': 2147483647, 'p': 1986897071, 'b': 7071}), 17]
# snd b
# [7071, defaultdict(<class 'int'>, {'i': 1, 'a': 2147483647, 'p': 1986897071, 'b': 7071}), 18]
# add i -1
# [7071, defaultdict(<class 'int'>, {'i': 0, 'a': 2147483647, 'p': 1986897071, 'b': 7071}), 19]
# jgz i -9
# [7071, defaultdict(<class 'int'>, {'i': 0, 'a': 2147483647, 'p': 1986897071, 'b': 7071}), 20]
# jgz a 3
# [7071, defaultdict(<class 'int'>, {'i': 0, 'a': 2147483647, 'p': 1986897071, 'b': 7071}), 23]
# set f 0
# [7071, defaultdict(<class 'int'>, {'i': 0, 'a': 2147483647, 'p': 1986897071, 'b': 7071, 'f': 0}), 24]
# set i 126
# [7071, defaultdict(<class 'int'>, {'i': 126, 'a': 2147483647, 'p': 1986897071, 'b': 7071, 'f': 0}), 25]
# rcv a
# 7071
