# %% [markdown]
# So for part 2, we should also find the weight that each disk supports. So we'll want some new structures, let's use `dict`s, which implement the tree structures, and the weight distributions.
#
# Let's start off by creating a tree that represents just the structure of the tower; we can worry about the weights after:

# %%
import re

from collections import Counter

# %% [markdown]
# Start with the example input again:

# %%
input_str='''pbga (66)
xhth (57)
ebii (61)
havc (66)
ktlj (57)
fwft (72) -> ktlj, cntj, xhth
qoyq (66)
padx (45) -> pbga, havc, qoyq
tknk (41) -> ugml, padx, fwft
jptl (61)
ugml (68) -> gyxo, ebii, jptl
gyxo (61)
cntj (57)'''

# %% [markdown]
# Let's go through each line: if it contains balancing information, add that to a set `supported_set`, and add any other cases to a set `disks_set`.

# %% [markdown]
# This time, rather than simply adding to a set `supported_set`, let's use a dict which implements the tree structure of the tower. I'm also changing the disks representation, so that we store the weight, and eventually, the total supported weight:

# %%
disks_dict={}

for nextLine_str in input_str.split('\n'):
    if '->' in nextLine_str:
        m_re=re.match('\s*(?P<name>\w+) \((?P<weight>\d+)\) ->(?P<rest>.*)', nextLine_str)
        
        disks_dict[m_re.group('name')]={'weight':int(m_re.group('weight')),
                                        'supporting':{disk.strip() for disk in m_re.group('rest').split(',')}}
    else:
        m_re=re.match('\s*(?P<name>\w+) \((?P<weight>\d+)\)', nextLine_str)
        
        disks_dict[m_re.group('name')]={'weight':int(m_re.group('weight'))}
print(disks_dict)
# Out:
# {'pbga': {'weight': 66}, 'xhth': {'weight': 57}, 'ebii': {'weight': 61}, 'havc': {'weight': 66}, 'ktlj': {'weight': 57}, 'fwft': {'weight': 72, 'supporting': {'cntj', 'xhth', 'ktlj'}}, 'qoyq': {'weight': 66}, 'padx': {'weight': 45, 'supporting': {'pbga', 'havc', 'qoyq'}}, 'tknk': {'weight': 41, 'supporting': {'padx', 'ugml', 'fwft'}}, 'jptl': {'weight': 61}, 'ugml': {'weight': 68, 'supporting': {'gyxo', 'jptl', 'ebii'}}, 'gyxo': {'weight': 61}, 'cntj': {'weight': 57}}

# %% [markdown]
# And now find the disk which isn't in one of the `supporting` sets:

# %%
nonRoot_set=set()
for vals in disks_dict.values():
    nonRoot_set=nonRoot_set.union(vals.get('supporting', {}))
nonRoot_set

rootDisk_str=(set(disk for disk in disks_dict)-nonRoot_set).pop()
rootDisk_str
# Out:
# 'tknk'

# %% [markdown]
# Now build the total weight (own weight + supported weights) recursively:

# %%
def set_total_weights(startDisk_str, disksIn_dict):
    '''
    Find the total weight supported (including itself) by each
    disk in the tower. Update disksIn_ls with those weights.
    
    Returns the total weight on startDisk_str
    '''
    
    # If the disk is not supporting any other disks:
    if 'supporting' not in disksIn_dict[startDisk_str]:
        # Set the totalWeight to the disk's own weight, and
        # return that value
        disksIn_dict[startDisk_str]['totalWeight']=disksIn_dict[startDisk_str]['weight']
        return disksIn_dict[startDisk_str]['totalWeight']
    
    # Otherwise, build the total weights from the start
    # disk recursively:
    else:
        disksIn_dict[startDisk_str]['totalWeight'] = \
            sum([set_total_weights(d, disksIn_dict) 
                 for d in disksIn_dict[startDisk_str]['supporting']]) + \
            disksIn_dict[startDisk_str]['weight']
        return disksIn_dict[startDisk_str]['totalWeight']
        

print(set_total_weights('tknk', disks_dict))
print()
disks_dict
# Out:
# 778
# {'cntj': {'totalWeight': 57, 'weight': 57},
#  'ebii': {'totalWeight': 61, 'weight': 61},
#  'fwft': {'supporting': {'cntj', 'ktlj', 'xhth'},
#   'totalWeight': 243,
#   'weight': 72},
#  'gyxo': {'totalWeight': 61, 'weight': 61},
#  'havc': {'totalWeight': 66, 'weight': 66},
#  'jptl': {'totalWeight': 61, 'weight': 61},
#  'ktlj': {'totalWeight': 57, 'weight': 57},
#  'padx': {'supporting': {'havc', 'pbga', 'qoyq'},
#   'totalWeight': 243,
#   'weight': 45},
#  'pbga': {'totalWeight': 66, 'weight': 66},
#  'qoyq': {'totalWeight': 66, 'weight': 66},
#  'tknk': {'supporting': {'fwft', 'padx', 'ugml'},
#   'totalWeight': 778,
#   'weight': 41},
#  'ugml': {'supporting': {'ebii', 'gyxo', 'jptl'},
#   'totalWeight': 251,
#   'weight': 68},
#  'xhth': {'totalWeight': 57, 'weight': 57}}

# %% [markdown]
# So we seem to be building the tower correctly. Now we need to work out which is the incorrect weight.

# %% [markdown]
# Actually, we don't need to be too bothered about finding precisly which is the incorrect disk: we only need to find out which is the odd one out, and return the weight of the others.

# %%
def odd_one_out(dictIn_dict):
    '''
    Take a dictionary of key:value pairs. Return the
    triple (name, totalWeight, otherWeight) of the odd one 
    out, where otherWeight is the weight of the other members
    of the list. False if there isn't one.
    '''

    # Return False if all keys have same value    
    if len(set(dictIn_dict.values()))==1:
        return False

    # Raise an error if more than two values:
    assert len(set(dictIn_dict.values()))<=2, "too many values"

    # Raise an error if not a single exception:
    cc=sorted(Counter(dictIn_dict.values()).values())
    assert cc[0]==1 and cc[1]>1, "too many values"
    
    # Otherwise, find the odd one out and return the triple:
    keys_ls=list(dictIn_dict)
    
    # Get the values of the first two keys:
    v0=dictIn_dict[keys_ls[0]]
    v1=dictIn_dict[keys_ls[1]]
    
    # If they're different, get the next value:
    if v0!=v1:
        v2=dictIn_dict[keys_ls[2]]
        # ... and return the appropriate triple
        if v0==v2:
            return (keys_ls[1], v1, v0)
        else:
            return (keys_ls[0], v0, v1)
    else:
        # Otherwise, loop until find the exception...
        for key in keys_ls:
            if dictIn_dict[key]!=v0:
                # ... and return the triple
                return (key, dictIn_dict[key], v0)

dictIn_dict={'a':2, 'b':3, 'c':3, 'd':3}
odd_one_out(dictIn_dict)
# Out:
# ('a', 2, 3)

# %% [markdown]
# OK. Those are the preliminaries. Now we should just be able to run through the disk dictionary and make the adjustment when we find the odd one out:

# %%
def find_incorrect_disk(startDisk_str, disksIn_dict, weightDiff_i=0):
    '''Return the disk with the change that needs to be made to its weight'''
    # Get the weights on the current disk:
    weightsOnCurrent_dict={disk:disks_dict[disk]['totalWeight'] 
                           for disk in disksIn_dict[startDisk_str]['supporting']}
    # If the weights on the current disk are equal, return
    # the current disk:
    if len(set(weightsOnCurrent_dict.values()))==1:
        return (startDisk_str, weightDiff_i)
    
    # otherwise, apply the function to the odd one out:
    (d, w1, w2)=odd_one_out(weightsOnCurrent_dict)
    return find_incorrect_disk(d, disksIn_dict, w2-w1)
    
find_incorrect_disk('tknk', disks_dict)
# Out:
# ('ugml', -8)

# %% [markdown]
# Actually, to solve it, we need to add the final argument returned by `find_incorrect_disk` to the weight of the disk in question:

# %%
(d, c)=find_incorrect_disk('tknk', disks_dict)

disks_dict[d]['weight']+c
# Out:
# 60

# %% [markdown]
# OK, that's the right answer, although I can't help thinking I might have made rather heavy weather of that one. Still, let's do it with my input:

# %%
with open('data/day7.txt') as fIn:
    input_str=fIn.read()

# %%
disks_dict={}

for nextLine_str in input_str.split('\n'):
    if '->' in nextLine_str:
        m_re=re.match('\s*(?P<name>\w+) \((?P<weight>\d+)\) ->(?P<rest>.*)', nextLine_str)
        
        disks_dict[m_re.group('name')]={'weight':int(m_re.group('weight')),
                                        'supporting':{disk.strip() for disk in m_re.group('rest').split(',')}}
    else:
        m_re=re.match('\s*(?P<name>\w+) \((?P<weight>\d+)\)', nextLine_str)
        if m_re:
            disks_dict[m_re.group('name')]={'weight':int(m_re.group('weight'))}
disks_dict
# Out:
# {'nzyiue': {'weight': 57},
#  'pdmkag': {'weight': 39},
#  'bogbg': {'weight': 13},
#  'nubay': {'weight': 45},
#  'dukzh': {'weight': 17},
#  'kpjxln': {'supporting': {'dzzbvkv', 'gzdxgvj', 'jidxg', 'wsocb'},
#   'weight': 44},
#  'cxjyxl': {'weight': 83},
#  'vusplt': {'supporting': {'mcfst', 'orrwx'}, 'weight': 151},
#  'mxrfq': {'weight': 98},
#  'bdoez': {'weight': 62},
#  'vrajpg': {'weight': 78},
#  'qzsowpu': {'weight': 90},
#  'nrxoha': {'weight': 51},
#  'xtjrkv': {'supporting': {'jlbhafs', 'pyocxtt'}, 'weight': 351},
#  'rlnii': {'supporting': {'ljvpv', 'wkumzkr', 'xjosf'}, 'weight': 18986},
#  'ddrrgp': {'weight': 23},
#  'wladmn': {'weight': 42},
#  'ryskzh': {'supporting': {'wsyya', 'xbqpjo'}, 'weight': 209},
#  'jbjkp': {'weight': 34},
#  'fnfiur': {'weight': 86},
#  'zxzkl': {'weight': 82},
#  'hbmxey': {'supporting': {'khkuxc', 'miauii', 'mjuwde', 'tztycfl'},
#   'weight': 1869},
#  'zjyqcfa': {'weight': 97},
#  'zbtck': {'weight': 48},
#  'mgsasl': {'weight': 39},
#  'cemygp': {'weight': 34},
#  'iolrkmv': {'supporting': {'itxtmhb', 'rntjx'}, 'weight': 139},
#  'jzmqzl': {'supporting': {'mwfryd', 'pptocz', 'sflwom', 'utgkveb'},
#   'weight': 1446},
#  'wagpkyw': {'weight': 88},
#  'saiyjff': {'weight': 67},
#  'kwwhb': {'supporting': {'htvpmr', 'rojhup'}, 'weight': 219},
#  'huspq': {'weight': 74},
#  'mzrafi': {'weight': 44},
#  'fchlc': {'weight': 89},
#  'ezkddph': {'weight': 62},
#  'zehnmg': {'weight': 5},
#  'tgirh': {'weight': 50},
#  'xantdh': {'weight': 73},
#  'zicvvl': {'weight': 10},
#  'kcimi': {'supporting': {'iuovz', 'kmhyz', 'uwizfa', 'wagpkyw'},
#   'weight': 86},
#  'wsocb': {'weight': 64},
#  'aemffo': {'supporting': {'dukzh', 'tpubu', 'vczudlu'}, 'weight': 284},
#  'gfgoc': {'weight': 18},
#  'bmovg': {'weight': 80},
#  'trsnrjd': {'supporting': {'fstzdn', 'oujkd'}, 'weight': 89},
#  'bmqiwai': {'supporting': {'bwgkn', 'cgzyc', 'giftd', 'hdhvzi', 'yqeaqcn'},
#   'weight': 12928},
#  'ktehtif': {'supporting': {'fvplhrm', 'jesphm'}, 'weight': 151},
#  'jkfyg': {'supporting': {'ajeisgv', 'hvhtokr', 'jfrooen'}, 'weight': 76},
#  'dkfepj': {'supporting': {'mnsqjxv', 'tgirh'}, 'weight': 1970},
#  'jjseenh': {'weight': 99},
#  'jvpecm': {'supporting': {'bflxonp', 'dpyuayl', 'lyigbhi', 'tddik', 'tvcyh'},
#   'weight': 7},
#  'silklk': {'weight': 59},
#  'swscfel': {'weight': 68},
#  'dilefzx': {'weight': 89},
#  'spthyf': {'weight': 75},
#  'tiiwbg': {'weight': 17},
#  'ayqgp': {'weight': 58},
#  'qhygx': {'weight': 14},
#  'hqccsb': {'supporting': {'bdkfx', 'srrxb'}, 'weight': 26},
#  'lbojqfo': {'weight': 34},
#  'arbebt': {'weight': 32},
#  'fsvkj': {'supporting': {'ftqtzxk', 'otvvje', 'twzgms'}, 'weight': 115},
#  'sdigtox': {'weight': 39},
#  'awsphe': {'weight': 79},
#  'lftlc': {'weight': 35},
#  'apzabs': {'weight': 68},
#  'aboilvw': {'weight': 452},
#  'rntylx': {'weight': 44},
#  'xhhfsuw': {'weight': 280},
#  'yucwtc': {'weight': 41},
#  'qlgkqk': {'supporting': {'acdkw', 'hyfswg', 'sqfrw', 'wcinck', 'ycinfxk'},
#   'weight': 54},
#  'thneyz': {'weight': 57},
#  'pplkoa': {'weight': 79},
#  'vsxzpf': {'supporting': {'fkmccg', 'spyxh', 'yvcbk'}, 'weight': 197},
#  'miymiit': {'supporting': {'jxulvx', 'lmmeg', 'yqergs'}, 'weight': 1002},
#  'jaamgi': {'weight': 45},
#  'tvwosmc': {'supporting': {'frvmu', 'jemmk', 'qmfmfxh'}, 'weight': 1462},
#  'ngemsu': {'weight': 85},
#  'ohiftl': {'supporting': {'loggp', 'xhwfcu'}, 'weight': 143},
#  'bztor': {'supporting': {'gjfkx', 'grsdifs', 'spchmoq'}, 'weight': 157},
#  'tifkr': {'weight': 52},
#  'kgctcau': {'weight': 82},
#  'yvcbk': {'weight': 32},
#  'srvwd': {'supporting': {'dxerl', 'pzjsf', 'yqyyoj'}, 'weight': 1234},
#  'xrise': {'weight': 358},
#  'biwdu': {'supporting': {'bfpvsfz', 'fvfitqc', 'hlullj', 'kvpju'},
#   'weight': 70},
#  'utgkveb': {'supporting': {'fmhjs', 'mznkfco', 'pplkoa'}, 'weight': 76},
#  'mvhqou': {'supporting': {'culvtcm', 'njgzn', 'okfcek', 'zjyqcfa'},
#   'weight': 22},
#  'gadyi': {'supporting': {'efwhif', 'ndxim'}, 'weight': 398},
#  'ujzofuy': {'weight': 39},
#  'jjgem': {'supporting': {'fbuklc', 'gnffzh', 'hnvybq'}, 'weight': 852},
#  'rbucosf': {'supporting': {'jvpgl', 'yuhioxl'}, 'weight': 122},
#  'ffxnegs': {'supporting': {'cjlxgf',
#    'cocau',
#    'iazte',
#    'vusplt',
#    'xjxjaq',
#    'yjonn',
#    'zfcylzq'},
#   'weight': 222},
#  'wrtyhxg': {'supporting': {'idivffq', 'jbvugg', 'vindf', 'zqckoxe'},
#   'weight': 403},
#  'imbpvgl': {'weight': 52},
#  'frrvvai': {'supporting': {'gxcnp', 'zvjrwke'}, 'weight': 193},
#  'ywlrls': {'supporting': {'cxndroi', 'dfyqo', 'gbpcav', 'gqdxrur'},
#   'weight': 31},
#  'olzdhtj': {'weight': 42},
#  'thvjlgo': {'supporting': {'cufudi', 'jdyspx'}, 'weight': 76},
#  'jearhat': {'weight': 57},
#  'jxanwhq': {'weight': 27},
#  'wsyya': {'weight': 98},
#  'tahstqe': {'weight': 37},
#  'dyvooj': {'weight': 80},
#  'yuypmb': {'weight': 98},
#  'uehdbi': {'weight': 26},
#  'inspqeu': {'weight': 34},
#  'nxqqsza': {'supporting': {'guxwd', 'iyxkzat'}, 'weight': 119},
#  'jgkmy': {'weight': 86},
#  'hllzej': {'supporting': {'ekfpabq', 'sodrm', 'utqxb'}, 'weight': 154},
#  'gcbvf': {'weight': 68},
#  'ctoxz': {'weight': 98},
#  'advlxrg': {'weight': 22},
#  'eetxll': {'weight': 37},
#  'lmpauyz': {'weight': 72},
#  'lwxts': {'weight': 76},
#  'rkuyxrc': {'weight': 55},
#  'pitdti': {'weight': 55},
#  'ucjew': {'weight': 91},
#  'gynwftf': {'weight': 91},
#  'czojwyg': {'weight': 15},
#  'uigoxw': {'weight': 75},
#  'rcjqfuo': {'supporting': {'lgoak', 'zcomcn'}, 'weight': 129},
#  'vvkbav': {'weight': 56},
#  'npcyutn': {'weight': 35},
#  'jfaoy': {'weight': 57},
#  'iqcgwzk': {'supporting': {'dukqd', 'gxdtiob', 'pdepl', 'ylnvdoq', 'zxeopkg'},
#   'weight': 58},
#  'rqnsxm': {'supporting': {'bolxwme', 'dgsse', 'jaxig'}, 'weight': 2056},
#  'bsyiv': {'weight': 38},
#  'hhnpg': {'supporting': {'dmvajb', 'pvwdkm'}, 'weight': 164},
#  'oydoajo': {'weight': 87},
#  'fowpeur': {'weight': 85},
#  'ycnih': {'weight': 17},
#  'zwpyj': {'weight': 12},
#  'wpprf': {'supporting': {'fdthu', 'sxslizl'}, 'weight': 97},
#  'icqsww': {'weight': 55},
#  'ckedyqu': {'weight': 54},
#  'ageyuq': {'weight': 19},
#  'ebrgtq': {'supporting': {'bochc', 'ogafygg', 'wqdvql'}, 'weight': 112},
#  'ygteuy': {'weight': 89},
#  'tuhxr': {'weight': 76},
#  'rvuvico': {'weight': 91},
#  'ecjujqu': {'weight': 92},
#  'tvhgbau': {'weight': 79},
#  'zvsnz': {'weight': 26},
#  'fquywyi': {'weight': 308},
#  'gqrgh': {'weight': 24},
#  'zcfswa': {'weight': 37},
#  'hkbxj': {'weight': 55},
#  'cnknlru': {'supporting': {'sawqp', 'udfuty'}, 'weight': 70},
#  'jljnags': {'weight': 38},
#  'tztycfl': {'supporting': {'gqzemw', 'hsfxq', 'rrtqyew'}, 'weight': 939},
#  'xzyri': {'supporting': {'yakzm', 'zkikhk'}, 'weight': 187},
#  'sdzoy': {'weight': 51},
#  'ojtrl': {'supporting': {'hpgktb', 'phkvcix', 'pjkwlmk', 'zguqo'},
#   'weight': 130},
#  'lyhok': {'supporting': {'bilzbf',
#    'bwthm',
#    'hdpemqh',
#    'iqcgwzk',
#    'nfvsrpa',
#    'nrlvovz',
#    'sljgt'},
#   'weight': 95},
#  'hpanc': {'weight': 17},
#  'ykvtr': {'weight': 51},
#  'qbbmsf': {'weight': 97},
#  'ppfyonm': {'supporting': {'ecjrblb', 'ylwniqh'}, 'weight': 98},
#  'jdsdqzd': {'weight': 32},
#  'oujkd': {'weight': 97},
#  'dpija': {'weight': 23},
#  'pdjnnzd': {'weight': 85},
#  'ghzqyv': {'weight': 37},
#  'yvlxoom': {'supporting': {'wgwkss', 'yxoqwg'}, 'weight': 58},
#  'gjupqe': {'supporting': {'oszyw', 'zyqqzou'}, 'weight': 180},
#  'qmfmfxh': {'supporting': {'rkgxu', 'unrhnl'}, 'weight': 7},
#  'hxlefwp': {'supporting': {'ouxjkf', 'yablonq'}, 'weight': 268},
#  'fdthu': {'weight': 86},
#  'voonmio': {'weight': 63},
#  'uxlcvt': {'supporting': {'scipnb', 'veutu'}, 'weight': 143},
#  'xybcccw': {'weight': 7},
#  'inomnjg': {'weight': 91},
#  'gfuxooq': {'supporting': {'aceiy', 'axtzeb'}, 'weight': 221},
#  'xirqz': {'weight': 71},
#  'tuqzsn': {'supporting': {'hcyohc', 'hueqfk', 'nerlvh'}, 'weight': 73},
#  'jaxig': {'supporting': {'llofnny', 'snvqyqb'}, 'weight': 82},
#  'czztmlk': {'weight': 61},
#  'ffrilz': {'supporting': {'ckedyqu', 'qnvzqc'}, 'weight': 148},
#  'ejslpy': {'supporting': {'ayirpk',
#    'bapvub',
#    'gnrqrsj',
#    'jzdmjdf',
#    'kvifa',
#    'wwcih'},
#   'weight': 5616},
#  'bfwbkxq': {'supporting': {'hiqhe', 'jkfyg', 'ouqwmnj', 'wqxcn'},
#   'weight': 493},
#  'upftju': {'weight': 48},
#  'bqcizg': {'weight': 67},
#  'mkyqul': {'weight': 5},
#  'wjjar': {'supporting': {'nsvrfae', 'ywutc'}, 'weight': 296},
#  'pabgfh': {'supporting': {'bogbg', 'hgcxyx', 'siisskc'}, 'weight': 244},
#  'oltky': {'weight': 7},
#  'aeapmwq': {'weight': 76},
#  'btjxv': {'supporting': {'ripmztc', 'wpgyc'}, 'weight': 35},
#  'onuxzz': {'weight': 247},
#  'ahayh': {'supporting': {'byrvfhp', 'ejslpy', 'rokie'}, 'weight': 54732},
#  'idooz': {'supporting': {'owxuzp', 'uehdbi'}, 'weight': 192},
#  'ghjpcv': {'supporting': {'ebktv', 'xucdiz', 'ygrbgm', 'yxqesmi'},
#   'weight': 162},
#  'zhffrzu': {'weight': 42},
#  'bpygf': {'weight': 26},
#  'tojpm': {'weight': 42},
#  'iihzs': {'supporting': {'enekg', 'hkbxj'}, 'weight': 67},
#  'ydpihb': {'weight': 46},
#  'rgssc': {'weight': 27},
#  'dkgsvl': {'weight': 82},
#  'qrfhxne': {'weight': 65},
#  'sntuz': {'weight': 68},
#  'oznhe': {'supporting': {'cpvlq', 'tgvdjhh'}, 'weight': 98},
#  'evfqyvl': {'weight': 304},
#  'qftqq': {'weight': 27},
#  'yxcbn': {'weight': 11},
#  'buifcn': {'weight': 15},
#  'xbpqmua': {'weight': 25},
#  'vjroix': {'weight': 85},
#  'evqrr': {'weight': 48},
#  'unrhnl': {'weight': 88},
#  'ihuzl': {'weight': 35},
#  'giftd': {'supporting': {'qcolnc', 'vyaoad', 'zbedu'}, 'weight': 1250},
#  'uqjmbb': {'weight': 17},
#  'egulpbe': {'weight': 80},
#  'fpmwz': {'weight': 218},
#  'nihmyu': {'weight': 98},
#  'avaoo': {'supporting': {'xsufhnb', 'xxshup'}, 'weight': 176},
#  'fmqon': {'weight': 61},
#  'mbokr': {'weight': 57},
#  'gprznw': {'weight': 41},
#  'bflxonp': {'supporting': {'jearhat', 'pdmsm'}, 'weight': 105},
#  'oylgfzb': {'supporting': {'bmqiwai', 'gwznzk', 'hbgyu', 'rlnii', 'rugzyaj'},
#   'weight': 65},
#  'cepqh': {'weight': 19},
#  'hfjhadi': {'weight': 58},
#  'ajtkddh': {'weight': 60},
#  'vyadxnv': {'supporting': {'adueu',
#    'cbvjwlo',
#    'ijleirw',
#    'mdpcfvu',
#    'pyntdrr',
#    'qlkqplv',
#    'sltrdk'},
#   'weight': 94},
#  'anvvug': {'supporting': {'kgctcau', 'tfuxhhz'}, 'weight': 1847},
#  'tjobe': {'supporting': {'hdspavt', 'mcduq'}, 'weight': 129},
#  'qvgeei': {'weight': 273},
#  'dkxsqjt': {'supporting': {'cuwqi', 'fcoxtp', 'yvlxoom'}, 'weight': 1416},
#  'urwgjd': {'weight': 39},
#  'vxqcf': {'supporting': {'gfnapwr', 'lmpauyz'}, 'weight': 105},
#  'etnkepp': {'weight': 5},
#  'koyke': {'weight': 15},
#  'qqhjlu': {'weight': 78},
#  'glguoq': {'weight': 75},
#  'hdvfyp': {'supporting': {'cksyln', 'eoaprcr', 'hknzmvs'}, 'weight': 7},
#  'pqvid': {'weight': 15},
#  'jesphm': {'weight': 6},
#  'bdkfx': {'weight': 81},
#  'gqdxrur': {'weight': 77},
#  'fmifd': {'weight': 94},
#  'ijiqjtf': {'weight': 63},
#  'dfyqo': {'weight': 77},
#  'spchmoq': {'weight': 31},
#  'tvcyh': {'supporting': {'lqbtnb', 'matcdld'}, 'weight': 149},
#  'ilzwrk': {'weight': 64},
#  'tdtznh': {'supporting': {'offas', 'phacwjs'}, 'weight': 64},
#  'tygst': {'weight': 91},
#  'uzjoys': {'supporting': {'bgcjrf', 'zdrfiw'}, 'weight': 198},
#  'wfbuzbg': {'supporting': {'ajrcal', 'qpuyqq'}, 'weight': 47},
#  'kwqcbe': {'weight': 19},
#  'qdovgra': {'supporting': {'gfgoc', 'zziyhz'}, 'weight': 303},
#  'vfcbliu': {'weight': 19},
#  'fwtfkp': {'weight': 325},
#  'rmdqvgh': {'weight': 61},
#  'dtjzr': {'weight': 28},
#  'cocau': {'supporting': {'ficmghd', 'nkejtw', 'qowyx'}, 'weight': 77},
#  'aftsom': {'weight': 70},
#  'fsmzljm': {'supporting': {'hnfeims', 'tatjry'}, 'weight': 123},
#  'lwufmc': {'weight': 45},
#  'fzzcxvm': {'weight': 61},
#  'cxokosi': {'supporting': {'gatdr', 'sszzop'}, 'weight': 70},
#  'mmlra': {'supporting': {'jexreg',
#    'lhnevgo',
#    'lzowumq',
#    'rcjqfuo',
#    'smuybnw',
#    'wdlwryo',
#    'wpprf'},
#   'weight': 32},
#  'tydlqpq': {'supporting': {'fsbojm', 'mjlmuca'}, 'weight': 160},
#  'oevvote': {'supporting': {'erysec', 'polrzc', 'silklk', 'xoyjtol'},
#   'weight': 68},
#  'fxsatsm': {'supporting': {'qgxcbt', 'sntuz'}, 'weight': 83},
#  'cvvtz': {'supporting': {'rgssc', 'vpjhl'}, 'weight': 80},
#  'feonsg': {'weight': 74},
#  'htvpmr': {'weight': 7},
#  'gqzemw': {'supporting': {'jtvntr', 'pxdgkik'}, 'weight': 43},
#  'pvpqoq': {'weight': 17},
#  'ldfmurk': {'supporting': {'aemffo', 'fubtwbq', 'mszwp', 'sqsqge', 'ycawl'},
#   'weight': 88},
#  'aufym': {'weight': 51},
#  'ldflo': {'weight': 188},
#  'izyjved': {'weight': 5},
#  'zgydn': {'weight': 72},
#  'cqfri': {'weight': 9},
#  'ytnti': {'supporting': {'fugeht', 'lamtp'}, 'weight': 150},
#  'appkqpe': {'weight': 95},
#  'sjxbk': {'supporting': {'amwtic', 'tinbqcj'}, 'weight': 117},
#  'fbvvrqt': {'weight': 81},
#  'vlwjehz': {'weight': 22},
#  'lwhev': {'supporting': {'hpjgrb', 'sxbusu', 'wmwzhjg', 'zesvlul'},
#   'weight': 44},
#  'hugfkt': {'weight': 42},
#  'tnobvt': {'weight': 18},
#  'zesvlul': {'weight': 73},
#  'gfnapwr': {'weight': 72},
#  'tabzzo': {'supporting': {'inomnjg', 'rvuvico'}, 'weight': 62},
#  'ixdcgsa': {'supporting': {'cogovv', 'gmhxee'}, 'weight': 177},
#  'fnvgp': {'weight': 85},
#  'awhwxdm': {'weight': 91},
#  'frgot': {'weight': 59},
#  'boete': {'supporting': {'ionnnfx', 'ouhfxyf', 'vytdgko'}, 'weight': 78},
#  'ikxewmm': {'weight': 14},
#  'qfkka': {'weight': 49},
#  'xidye': {'weight': 11},
#  'krdlzf': {'weight': 115},
#  'hxjhcuc': {'supporting': {'iolrkmv', 'miuvc', 'trsnrjd'}, 'weight': 694},
#  'ikbkb': {'supporting': {'spthyf', 'uigoxw'}, 'weight': 136},
#  'yqeaqcn': {'supporting': {'bhzbv',
#    'evfqyvl',
#    'hxlefwp',
#    'mkjvhl',
#    'qysdgq',
#    'usuujhq'},
#   'weight': 53},
#  'dnrxyh': {'supporting': {'cqpns', 'fxsatsm', 'xthhlfy', 'xzyri'},
#   'weight': 887},
#  'siswh': {'weight': 41},
#  'pfxrf': {'weight': 51},
#  'dlzgufq': {'supporting': {'dnrxyh', 'dzetsz', 'ldfmurk'}, 'weight': 7462},
#  'whlfwr': {'weight': 46},
#  'gbiluq': {'weight': 11},
#  'euaceg': {'weight': 42},
#  'iwdesog': {'supporting': {'cqyluwl', 'dbeskg'}, 'weight': 152},
#  'afjmzb': {'weight': 15},
#  'sofxmjx': {'weight': 83},
#  'ortcrq': {'weight': 18},
#  'phacwjs': {'weight': 58},
#  'uiwgpi': {'supporting': {'caihc', 'hqvvrd', 'rvxed'}, 'weight': 995},
#  'oiyxr': {'supporting': {'sbklnq', 'zibbm'}, 'weight': 86},
#  'yukoxaw': {'weight': 27},
#  'orrwx': {'weight': 47},
#  'tlxbtng': {'weight': 44},
#  'ayirpk': {'supporting': {'cdkcn', 'wbllfh', 'xounvb'}, 'weight': 1850},
#  'lqjznss': {'weight': 67},
#  'mldkiku': {'weight': 55},
#  'dyfhy': {'weight': 58},
#  'jxulvx': {'supporting': {'ujzjt', 'ykmej'}, 'weight': 34},
#  'yuhioxl': {'weight': 20},
#  'uwiza': {'supporting': {'bnvjmae', 'hxaza', 'lddiw', 'oltky'},
#   'weight': 106},
#  'hpsxqdm': {'supporting': {'azdklp', 'luzcpkn', 'rupdbwl', 'vwqog'},
#   'weight': 41},
#  'fubtwbq': {'supporting': {'bdoez', 'ezkddph'}, 'weight': 211},
#  'cwgbjaq': {'weight': 41},
#  'kmhyz': {'weight': 88},
#  'tpubu': {'weight': 17},
#  'bfrbwb': {'weight': 27},
#  'mgwauar': {'weight': 8},
#  'ixwyi': {'weight': 13},
#  'ljugvh': {'supporting': {'gnwjseo',
#    'iaiywwa',
#    'ibjbozh',
#    'nvtbk',
#    'nxrkz',
#    'pcdtne',
#    'vobfi'},
#   'weight': 7},
#  'rcongvf': {'weight': 20},
#  'csqyn': {'weight': 46},
#  'ygbyt': {'weight': 15},
#  'gwznzk': {'supporting': {'ehqavsc',
#    'fqhag',
#    'heuyaxx',
#    'ovqhdvy',
#    'yimottm',
#    'yirkbjn',
#    'zzxlo'},
#   'weight': 11},
#  'wwcih': {'supporting': {'cyfuwdb', 'dyveac', 'pejho', 'tojnst'},
#   'weight': 1585},
#  'alqog': {'supporting': {'dyvooj', 'wvkaie'}, 'weight': 157},
#  'qecgvu': {'weight': 19},
#  'jexreg': {'supporting': {'bonnse', 'phgkg'}, 'weight': 209},
#  'vbisx': {'weight': 49},
#  'bcukkvc': {'weight': 72},
#  'trcbs': {'weight': 90},
#  'xjxjaq': {'supporting': {'kfhwxyy', 'vnmxsi'}, 'weight': 211},
#  'uptgby': {'supporting': {'eocoy', 'lqjznss', 'petluuh'}, 'weight': 16},
#  'rjnht': {'weight': 63},
#  'urhwog': {'supporting': {'fwqru', 'mxscf'}, 'weight': 146},
#  'caihc': {'supporting': {'kzjkjz', 'rjijdre'}, 'weight': 158},
#  'mwjtydb': {'weight': 15},
#  'eqahcc': {'weight': 73},
#  'rntjx': {'weight': 72},
#  'ripmztc': {'weight': 96},
#  'cksyln': {'weight': 93},
#  'ktfeae': {'supporting': {'asoirn', 'feonsg', 'jbxnffu'}, 'weight': 20},
#  'bdukt': {'weight': 71},
#  'jtxbfm': {'weight': 55},
#  'ebwtpod': {'weight': 66},
#  'fjerhwe': {'weight': 50},
#  'xxshup': {'weight': 66},
#  'jdyspx': {'weight': 97},
#  'nyxiai': {'supporting': {'ejvaoj', 'fbiqxqk', 'pjmci'}, 'weight': 73},
#  'dxznun': {'weight': 49},
#  'umwial': {'weight': 183},
#  'mnsqjxv': {'weight': 50},
#  'wtoive': {'supporting': {'goicjt', 'nfcru'}, 'weight': 80},
#  'zkzefwh': {'weight': 22},
#  'oszyw': {'weight': 78},
#  'ekxdjlp': {'weight': 60},
#  'tymor': {'weight': 6},
#  'jbydxyp': {'weight': 66},
#  'dzlqgrt': {'weight': 43},
#  'grsdifs': {'weight': 31},
#  'pdepl': {'supporting': {'fhlul', 'ulezwmd'}, 'weight': 238},
#  'mbunh': {'weight': 8},
#  'iwajy': {'weight': 70},
#  'lknchr': {'supporting': {'nercz', 'skmvkj'}, 'weight': 68},
#  'klpctiz': {'weight': 75},
#  'lazlx': {'weight': 8},
#  'fbuhz': {'supporting': {'aarioi', 'fbrvfk'}, 'weight': 159},
#  'kvifa': {'supporting': {'avaoo',
#    'fodud',
#    'fquywyi',
#    'jatvkwy',
#    'ndmcgpn',
#    'rjhfcl',
#    'vczcept'},
#   'weight': 69},
#  'ilydn': {'weight': 74},
#  'nerlvh': {'weight': 85},
#  'qqduoo': {'supporting': {'boete', 'tcrkcu', 'wgglzpb'}, 'weight': 735},
#  'gfxnuuk': {'weight': 34},
#  'amwtic': {'weight': 72},
#  'ltpban': {'weight': 87},
#  'klyso': {'supporting': {'egabi', 'hmdwqdq', 'qenjyl'}, 'weight': 67},
#  'jotxc': {'weight': 57},
#  'cqyluwl': {'weight': 9},
#  'siyuvy': {'weight': 52},
#  'bbsomm': {'supporting': {'izonhi', 'jjseenh'}, 'weight': 61},
#  'pzjsf': {'supporting': {'etnuzv', 'hrrampl'}, 'weight': 49},
#  'vshekb': {'weight': 34},
#  'zvjrwke': {'weight': 27},
#  'xekggcw': {'supporting': {'anvvug', 'dpfov', 'fneqe', 'tvwosmc'},
#   'weight': 89},
#  'hsulvq': {'weight': 78},
#  'idivffq': {'weight': 292},
#  'bapvub': {'supporting': {'acnvtg', 'dcpnyer', 'lvkpx', 'zeopgv'},
#   'weight': 821},
#  'ziwkz': {'supporting': {'eqzuic', 'qrtwjv'}, 'weight': 331},
#  'bvock': {'weight': 81},
#  'vsyuckp': {'weight': 54},
#  'bsoef': {'weight': 40},
#  'ncjhpa': {'weight': 247},
#  'axtzeb': {'weight': 13},
#  'yotlucw': {'supporting': {'ebwtpod', 'jbydxyp'}, 'weight': 134},
#  'ceqfbbl': {'weight': 33},
#  'qhbotj': {'weight': 62},
#  'hrmpq': {'weight': 90},
#  'pgznzly': {'weight': 13},
#  'vgndgst': {'weight': 72},
#  'auvla': {'weight': 65},
#  'ylnvdoq': {'weight': 350},
#  'fgxst': {'weight': 8},
#  'pptocz': {'supporting': {'hglhjt', 'werriw'}, 'weight': 287},
#  'lqbtnb': {'weight': 35},
#  'xvuri': {'weight': 293},
#  'dbeskg': {'weight': 9},
#  'crkapwa': {'supporting': {'npdwg', 'ogpka'}, 'weight': 87},
#  'bilzbf': {'supporting': {'brkux', 'cplvif', 'qcoyrha'}, 'weight': 803},
#  'byrvfhp': {'supporting': {'cgjula',
#    'csear',
#    'gqgewi',
#    'jzmqzl',
#    'luuxtc',
#    'rqnsxm',
#    'vyadxnv'},
#   'weight': 80},
#  'cqiipxn': {'weight': 84},
#  'oryrq': {'supporting': {'cabsaub', 'palqky', 'zfthi'}, 'weight': 103},
#  'gkzeqaw': {'supporting': {'hntdp', 'iyflfx'}, 'weight': 38},
#  'xqnrp': {'weight': 33},
#  'zcomcn': {'weight': 70},
#  'tjcpka': {'weight': 87},
#  'nfcru': {'weight': 41},
#  'vfpdqlb': {'weight': 43},
#  'msdff': {'weight': 82},
#  'tddik': {'supporting': {'btbses', 'vlthh'}, 'weight': 43},
#  'qlmojkv': {'supporting': {'ligpl', 'tymor', 'xkfuzi'}, 'weight': 264},
#  'sodrm': {'weight': 37},
#  'mvvgro': {'weight': 84},
#  'cbvjwlo': {'supporting': {'nsqzndf', 'synjm'}, 'weight': 270},
#  'kowco': {'supporting': {'gqrgh', 'nhxmab'}, 'weight': 46},
#  'xrapmvb': {'weight': 150},
#  'iifltp': {'supporting': {'fowpeur', 'vjroix'}, 'weight': 95},
#  'tinbqcj': {'weight': 72},
#  'lbjuqcd': {'weight': 19},
#  'hlhomy': {'supporting': {'ahayh',
#    'dxxty',
#    'hvtvcpz',
#    'lqirhg',
#    'oylgfzb',
#    'razvskj',
#    'teyrfjn'},
#   'weight': 30},
#  'veutu': {'weight': 53},
#  'tfuxhhz': {'weight': 82},
#  'oenrkia': {'weight': 44},
#  'oipjwtz': {'supporting': {'mjbjv', 'tgqpp'}, 'weight': 40},
#  'ndcjr': {'weight': 75},
#  'oermd': {'weight': 94},
#  'xsmgj': {'weight': 99},
#  'cfmhi': {'supporting': {'hoelsa', 'obrwb'}, 'weight': 107},
#  'nwyftp': {'weight': 72},
#  'nmdhmy': {'weight': 39},
#  'qslgo': {'weight': 92},
#  'mjbjv': {'weight': 89},
#  'hhvqa': {'weight': 41},
#  'erysec': {'weight': 59},
#  'xdnuvji': {'weight': 20},
#  'bfxezgb': {'weight': 8},
#  'njmrq': {'supporting': {'pdmkag', 'uufrda'}, 'weight': 192},
#  'gutukz': {'weight': 70},
#  'acjtwvt': {'weight': 98},
#  'kddchk': {'weight': 71},
#  'apzjw': {'supporting': {'jetfvjc', 'peomyg'}, 'weight': 149},
#  'xzhvvy': {'supporting': {'alcpfsx', 'ehxkgh', 'kvjqli', 'tjdap'},
#   'weight': 431},
#  'sowzlz': {'weight': 19},
#  'ucvgxii': {'weight': 85},
#  'uzprmq': {'supporting': {'exhxs', 'pfzqe', 'ygteuy'}, 'weight': 83},
#  'bvaor': {'weight': 35},
#  'gekcx': {'weight': 78},
#  'cxlip': {'weight': 44},
#  'psnkhtd': {'weight': 157},
#  'yimottm': {'supporting': {'fsmzljm',
#    'ickxyrm',
#    'nxqqsza',
#    'tvhfxfo',
#    'uptgby'},
#   'weight': 2101},
#  'ocbxx': {'weight': 66},
#  'acnvtg': {'supporting': {'nchjk', 'wbbfe'}, 'weight': 277},
#  'vangx': {'supporting': {'jdhiflw', 'xobyzo'}, 'weight': 51},
#  'sfoivjz': {'weight': 17},
#  'lunbob': {'weight': 66},
#  'ecabcm': {'supporting': {'advlxrg', 'vlwjehz'}, 'weight': 190},
#  'qarjx': {'weight': 7},
#  'gyktq': {'weight': 98},
#  'imfog': {'weight': 52},
#  'zsdvfrk': {'supporting': {'fvivhx', 'oxyxy', 'vxqcf'}, 'weight': 1190},
#  'zssgj': {'weight': 44},
#  'efbffd': {'weight': 20},
#  'etdofb': {'weight': 62},
#  'juakl': {'weight': 67},
#  'iltti': {'weight': 60},
#  'ffgoyk': {'supporting': {'jgdumgz', 'ltpban'}, 'weight': 74},
#  'lamtp': {'weight': 89},
#  'loggp': {'weight': 75},
#  'pejho': {'supporting': {'gxhia', 'mqaajk', 'tnobvt'}, 'weight': 106},
#  'enekg': {'weight': 55},
#  'cplvif': {'supporting': {'hqipq', 'lebqr', 'uhepxt', 'xfanpad'},
#   'weight': 95},
#  'dgsse': {'supporting': {'akrgdse', 'nwztmzp'}, 'weight': 88},
#  'rwjzc': {'supporting': {'lcufpmj', 'paqlttl', 'qrfhxne'}, 'weight': 107},
#  'drszzbe': {'supporting': {'tokvgmd', 'ucjew', 'unfgdb'}, 'weight': 132},
#  'vtnpx': {'weight': 79},
#  'rrkhcl': {'supporting': {'koemv', 'qnxnatu', 'seazs'}, 'weight': 26},
#  'ekfpabq': {'weight': 37},
#  'pwvmmda': {'supporting': {'hrkswsk', 'rntylx', 'zssgj'}, 'weight': 278},
#  'vqekr': {'weight': 85},
#  'luccp': {'supporting': {'ebrgtq', 'pslyfi', 'rvuktmb'}, 'weight': 175},
#  'xkfuzi': {'weight': 6},
#  'obaorae': {'weight': 45},
#  'dpfov': {'supporting': {'adasbyp', 'roqnodm', 'uorpbn', 'zjcdwr', 'zyonam'},
#   'weight': 96},
#  'lzowumq': {'supporting': {'aeapmwq', 'mtboq', 'sjthmr'}, 'weight': 41},
#  'pynxen': {'supporting': {'dpija', 'omzpkv', 'rwuxn', 'xgogpx'},
#   'weight': 152},
#  'itxtmhb': {'weight': 72},
#  'hanbscg': {'supporting': {'fffxc', 'jdjaem', 'lvuzab', 'npsza'},
#   'weight': 21},
#  'teyrfjn': {'supporting': {'ilfgats', 'qlgkqk', 'rnsxz', 'vyvcb'},
#   'weight': 62414},
#  'pocxfrt': {'weight': 39},
#  'mqecf': {'weight': 76},
#  'cpacyeu': {'weight': 67},
#  'gycde': {'weight': 88},
#  'tlhgrte': {'supporting': {'ejtoqaj', 'mmlra', 'xijwk'}, 'weight': 2388},
#  'jumdfk': {'weight': 64},
#  'swsffrv': {'weight': 13},
#  'fujvp': {'supporting': {'gwxkdy', 'hsftfol'}, 'weight': 155},
#  'dyxcd': {'weight': 87},
#  'ljvpv': {'supporting': {'euvkg', 'hoauxku', 'huutnfp'}, 'weight': 452},
#  'xydxl': {'weight': 88},
#  'ibdiplp': {'weight': 20},
#  'xvwqzt': {'supporting': {'ppdsem', 'pyhqixj', 'rjnht'}, 'weight': 70},
#  'djmoed': {'weight': 90},
#  'raioiq': {'supporting': {'inspqeu', 'ipdbccy'}, 'weight': 134},
#  'bwywt': {'weight': 67},
#  'jfvquxv': {'weight': 70},
#  'mtxzcd': {'supporting': {'ngemsu', 'ucvgxii'}, 'weight': 282},
#  'lfgmv': {'weight': 87},
#  'lcufpmj': {'weight': 65},
#  'pvwdkm': {'weight': 50},
#  'dbnstqf': {'weight': 56},
#  'jwgjnuu': {'weight': 33},
#  'ndmcgpn': {'supporting': {'bpygf', 'zvsnz'}, 'weight': 256},
#  'rktkzfw': {'weight': 35},
#  'zxeopkg': {'supporting': {'drnyyes', 'yjyipdp'}, 'weight': 218},
#  'nutlr': {'supporting': {'fjerhwe', 'xmrcq', 'ybuhf'}, 'weight': 116},
#  'cdkcn': {'supporting': {'dzlqgrt', 'vfpdqlb'}, 'weight': 39},
#  'jfrooen': {'weight': 95},
#  'xmrcq': {'weight': 50},
#  'qpuyqq': {'weight': 83},
#  'hiqhe': {'weight': 361},
#  'xuxlspe': {'weight': 44},
#  'apvfi': {'weight': 59},
#  'wahwi': {'supporting': {'boxvu', 'lnnii'}, 'weight': 303},
#  'affxphr': {'weight': 22},
#  'lhtzrh': {'weight': 213},
#  'yeewxiw': {'weight': 50},
#  'zyxjqs': {'weight': 65},
#  'kqgqdyg': {'supporting': {'tcihaf', 'yqctq'}, 'weight': 69},
#  'sqnfwo': {'weight': 67},
#  'mbqkm': {'weight': 12},
#  'mqaajk': {'weight': 18},
#  'nxhetg': {'weight': 60},
#  'hrxfpx': {'weight': 65},
#  'wjfsiec': {'supporting': {'czxbmp',
#    'doazn',
#    'tjbyhjw',
#    'vqqrb',
#    'vsxzpf',
#    'xvuri',
#    'znpqzc'},
#   'weight': 19},
#  'hsfxq': {'supporting': {'jtxbfm', 'lzhdsyq'}, 'weight': 99},
#  'lbiigt': {'weight': 26},
#  'bwgkn': {'supporting': {'cgnibii', 'urxxlfo', 'uzily', 'yqnbqgc'},
#   'weight': 1005},
#  'hpjgrb': {'weight': 73},
#  'ajpcyv': {'weight': 42},
#  'pirivl': {'supporting': {'bmovg', 'yexyj'}, 'weight': 144},
#  'szuiho': {'weight': 73},
#  'lnhiiq': {'weight': 64},
#  'yacaqwf': {'weight': 82},
#  'nqcadtp': {'supporting': {'akatbi', 'gncvcwi', 'kzvwk'}, 'weight': 310},
#  'bvgfpab': {'weight': 15},
#  'cxndroi': {'weight': 77},
#  'efwhif': {'weight': 6},
#  'njkxyjn': {'weight': 12},
#  'kvpju': {'weight': 39},
#  'gyyqk': {'supporting': {'coyroy',
#    'gzykr',
#    'jeshqdv',
#    'jtlhia',
#    'tqjpfzx',
#    'xzhvvy',
#    'ynwpoz'},
#   'weight': 5845},
#  'jwpqgy': {'supporting': {'fsixon', 'jxanwhq', 'lnsyuz'}, 'weight': 168},
#  'jwxff': {'supporting': {'ihtomiz', 'xeprhhl'}, 'weight': 95},
#  'yycux': {'weight': 15},
#  'fmhjs': {'weight': 79},
#  'wvieaw': {'weight': 67},
#  'iancjuu': {'weight': 39},
#  'vczcept': {'supporting': {'ipeig', 'muavtro'}, 'weight': 112},
#  'mwtusu': {'weight': 81},
#  'moewgvz': {'weight': 89},
#  'gmfktbe': {'weight': 31},
#  'dcpnyer': {'supporting': {'fmjyudw', 'icccxzg', 'nufpcxh', 'wuhyc'},
#   'weight': 67},
#  'hnfeims': {'weight': 47},
#  'rouiui': {'supporting': {'euiig',
#    'qlmojkv',
#    'tqlentr',
#    'txnzg',
#    'veqahi',
#    'zdkil'},
#   'weight': 30},
#  'bppos': {'weight': 37},
#  'hoauxku': {'weight': 219},
#  'ficmghd': {'weight': 56},
#  'lxpshey': {'weight': 95},
#  'hglhjt': {'weight': 13},
#  'oqbet': {'weight': 58},
#  'bsmxm': {'supporting': {'ewsrnsd', 'qzsowpu', 'trcbs'}, 'weight': 88},
#  'dxerl': {'supporting': {'kdujkg', 'njkxyjn'}, 'weight': 79},
#  'gxhia': {'weight': 18},
#  'eqifs': {'supporting': {'aqjkcss', 'cmeqx', 'jwlaj', 'uiwgpi'},
#   'weight': 3869},
#  'hqipq': {'weight': 60},
#  'upbmqk': {'weight': 18},
#  'culvtcm': {'weight': 97},
#  'cgdbu': {'weight': 90},
#  'tnrpi': {'supporting': {'xybcccw', 'zjtid'}, 'weight': 241},
#  'hlullj': {'weight': 39},
#  'ihcbt': {'weight': 44},
#  'wfjgqqm': {'weight': 55},
#  'dmzwm': {'weight': 86},
#  'hvtvcpz': {'supporting': {'dxcpj', 'eqifs', 'mdfbhs'}, 'weight': 81171},
#  'uufrda': {'weight': 39},
#  'lsfdgam': {'weight': 77},
#  'huutnfp': {'supporting': {'blrzef', 'ihllda'}, 'weight': 57},
#  'vnmxsi': {'weight': 17},
#  'tjbyhjw': {'supporting': {'cxlip', 'ihcbt', 'tlxbtng'}, 'weight': 161},
#  'fshvy': {'supporting': {'gynwftf', 'indgw'}, 'weight': 84},
#  'agsjzih': {'weight': 10},
#  'ppdsem': {'weight': 63},
#  'skmvkj': {'weight': 33},
#  'oxyxy': {'supporting': {'aawxzzs', 'tdnzc'}, 'weight': 205},
#  'ywavdk': {'weight': 67},
#  'pkxhxdz': {'supporting': {'fnvgp', 'gklur', 'vqekr'}, 'weight': 70},
#  'xsufhnb': {'weight': 66},
#  'ouhfxyf': {'weight': 97},
#  'dukqd': {'supporting': {'ndcjr', 'opyzwha', 'sfxsn', 'uystf'}, 'weight': 50},
#  'zybvpry': {'weight': 20},
#  'wwobe': {'weight': 34},
#  'bolxwme': {'supporting': {'jfvquxv', 'rsqexkv'}, 'weight': 74},
#  'adhilml': {'supporting': {'cqfri', 'mhassfj'}, 'weight': 299},
#  'icrnru': {'supporting': {'fuega', 'gutukz'}, 'weight': 160},
#  'oagluxi': {'weight': 40},
#  'ligpl': {'weight': 6},
#  'fttsg': {'supporting': {'ebtbnei', 'gmfktbe'}, 'weight': 255},
#  'ihtomiz': {'weight': 99},
#  'gblxcsj': {'supporting': {'kuaeh', 'pmfpitp'}, 'weight': 251},
#  'lrvxyg': {'supporting': {'lfgmv', 'ohtzuf'}, 'weight': 91},
#  'wuhyc': {'weight': 71},
#  'qjuud': {'supporting': {'ckexdc', 'oencfz'}, 'weight': 160},
#  'jbfzjha': {'supporting': {'mkyqul', 'txvuv', 'vbmhjxo', 'zehnmg'},
#   'weight': 305},
#  'xjosf': {'supporting': {'dfdgoj', 'tnrpi', 'xagwh', 'xkpulvc'},
#   'weight': 89},
#  'zkcwgx': {'weight': 22},
#  'ilbopwx': {'weight': 87},
#  'akatbi': {'supporting': {'pizkx', 'qjazr'}, 'weight': 222},
#  'uxuscb': {'supporting': {'jpeprwv', 'mdrir'}, 'weight': 249},
#  'hbgyu': {'supporting': {'jvpecm', 'nqcadtp', 'tkeoe'}, 'weight': 19007},
#  'kjzsi': {'weight': 56},
#  'cduzde': {'weight': 13},
#  'edoftkj': {'weight': 84},
#  'lxisjl': {'supporting': {'euqvd', 'hugfkt'}, 'weight': 86},
#  'owxuzp': {'weight': 26},
#  'nalhhj': {'supporting': {'dkfepj', 'dkxsqjt', 'egrga', 'wjfsiec'},
#   'weight': 4471},
#  'vcaekf': {'weight': 67},
#  'evwne': {'supporting': {'czztmlk', 'fmqon', 'fzzcxvm', 'rmdqvgh'},
#   'weight': 21},
#  'crojfnw': {'weight': 171},
#  'upiow': {'supporting': {'hukskkk', 'ilbopwx'}, 'weight': 82},
#  'srgua': {'supporting': {'hvefi', 'koyke'}, 'weight': 120},
#  'rcywun': {'supporting': {'fchlc', 'moewgvz'}, 'weight': 81},
#  'qlkqplv': {'supporting': {'ghuoa', 'hsulvq', 'ozwaa'}, 'weight': 138},
#  'czxbmp': {'supporting': {'arbebt', 'ieeqmzl', 'yzivqv'}, 'weight': 197},
#  'jjmyu': {'weight': 80},
#  'cyfuwdb': {'supporting': {'fwafvkf', 'mywmo', 'nppdvs'}, 'weight': 40},
#  'hmdwqdq': {'weight': 79},
#  'oencfz': {'weight': 10},
#  'pjkjcy': {'weight': 20},
#  'sxxhmpb': {'weight': 8},
#  'uwpwbgy': {'supporting': {'gbiluq', 'xidye'}, 'weight': 213},
#  'mywmo': {'weight': 40},
#  'rbmmiy': {'supporting': {'rwbhl', 'shkfk', 'umwial', 'vtono'},
#   'weight': 833},
#  'dmvajb': {'weight': 50},
#  'smuybnw': {'supporting': {'uktqwa', 'vdistyb'}, 'weight': 89},
#  'uagezb': {'supporting': {'hdvfyp', 'ikbkb', 'kwtukd'}, 'weight': 984},
#  'nrlvovz': {'supporting': {'kebff', 'oznhe', 'qoipc', 'uvhmzj'},
#   'weight': 840},
#  'vbmhjxo': {'weight': 5},
#  'ckafg': {'weight': 86},
#  'ovqhdvy': {'supporting': {'psnkhtd', 'trnjhsl', 'zxqix'}, 'weight': 2715},
#  'uktqwa': {'weight': 90},
#  'lzhdsyq': {'weight': 55},
#  'kofvzz': {'weight': 66},
#  'mcduq': {'weight': 60},
#  'qnsnc': {'weight': 62},
#  'kwtukd': {'supporting': {'bfrbwb', 'nhzmidl'}, 'weight': 232},
#  'zzavd': {'weight': 13},
#  'fmjyudw': {'weight': 71},
#  'vcnph': {'supporting': {'nnvpkf', 'wqgpm'}, 'weight': 161},
#  'lgamzp': {'weight': 64},
#  'ukqcayx': {'weight': 92},
#  'diduy': {'supporting': {'msdff', 'xwphya'}, 'weight': 116},
#  'izonhi': {'weight': 99},
#  'jetfvjc': {'weight': 16},
#  'rjhfcl': {'weight': 308},
#  'vqqrb': {'supporting': {'jfaoy', 'jhgxtg'}, 'weight': 179},
#  'tulxdf': {'supporting': {'bcukkvc', 'zgydn'}, 'weight': 308},
#  'rxuqpgb': {'supporting': {'aicncxc', 'aqogxi'}, 'weight': 144},
#  'spyxh': {'weight': 32},
#  'yqergs': {'supporting': {'kitsxb', 'woeoaa'}, 'weight': 100},
#  'bthswyg': {'weight': 34},
#  'rfaxua': {'supporting': {'dtyxosg', 'zugxr'}, 'weight': 81},
#  'fcoxtp': {'supporting': {'aqqdnpb', 'nkgmg'}, 'weight': 42},
#  'jbxnffu': {'weight': 74},
#  'bwthm': {'supporting': {'aqtml', 'jwxff', 'ohiftl'}, 'weight': 929},
#  'ionnnfx': {'weight': 97},
#  'urigx': {'supporting': {'eyozeel', 'xsmgj'}, 'weight': 141},
#  'nsggol': {'weight': 249},
#  'mgeseyn': {'supporting': {'hvacjk', 'pvgay'}, 'weight': 267},
#  'eqzuic': {'weight': 37},
#  'pxdgkik': {'weight': 83},
#  'zjqbfd': {'supporting': {'vfcbliu', 'viklkmp'}, 'weight': 188},
#  'wivwqm': {'weight': 74},
#  'nowyhln': {'weight': 52},
#  'sqsqge': {'supporting': {'amaeuv', 'paqvyfa'}, 'weight': 219},
#  'vynvu': {'weight': 87},
#  'ovysqnt': {'weight': 86},
#  'brfocu': {'supporting': {'agsjzih', 'ydhfmt', 'zbhahq', 'zicvvl'},
#   'weight': 230},
#  'dgumiir': {'supporting': {'inezd', 'kqrjpgl', 'olzdhtj'}, 'weight': 40},
#  'vpjhl': {'weight': 27},
#  'aqqdnpb': {'weight': 88},
#  'qaszsa': {'weight': 94},
#  'ajeisgv': {'weight': 95},
#  'aoscme': {'weight': 73},
#  'owlyge': {'weight': 65},
#  'kdqslsn': {'weight': 73},
#  'hukskkk': {'weight': 87},
#  'vindf': {'supporting': {'aoscme', 'fbdfh', 'szuiho'}, 'weight': 73},
#  'kosxb': {'supporting': {'itlsv', 'tcpujhx'}, 'weight': 140},
#  'oeaqbvl': {'supporting': {'bsyiv', 'fiqzxhc'}, 'weight': 142},
#  'lyigbhi': {'supporting': {'nzyiue', 'pqmye'}, 'weight': 105},
#  'trnjhsl': {'supporting': {'dtjzr', 'iinql', 'yhzwdu'}, 'weight': 73},
#  'mkucbvs': {'supporting': {'ikxewmm', 'qhygx'}, 'weight': 138},
#  'fvplhrm': {'weight': 6},
#  'qnvzqc': {'weight': 54},
#  'jdbub': {'weight': 48},
#  'opyzwha': {'weight': 75},
#  'xeprhhl': {'weight': 99},
#  'xounvb': {'supporting': {'mbqkm', 'zwpyj'}, 'weight': 101},
#  'aswpgvv': {'weight': 42},
#  'razvskj': {'supporting': {'dlzgufq', 'lyhok', 'nalhhj', 'xwifd'},
#   'weight': 60626},
#  'ygrbgm': {'weight': 172},
#  'tcrkcu': {'supporting': {'efbffd', 'ibdiplp'}, 'weight': 329},
#  'mijxl': {'weight': 63},
#  'ajfkd': {'weight': 9},
#  'aaaak': {'supporting': {'mdopg', 'mzrafi'}, 'weight': 6},
#  'qgnah': {'weight': 42},
#  'emppnct': {'weight': 78},
#  'qysdgq': {'supporting': {'klpctiz', 'uutlw'}, 'weight': 154},
#  'hkewsbw': {'weight': 89},
#  'lcfundi': {'weight': 52},
#  'iccpjfn': {'weight': 92},
#  'modzqb': {'weight': 30},
#  'nsqzndf': {'weight': 51},
#  'dpyuayl': {'supporting': {'cpacyeu', 'hwkwp', 'wvieaw'}, 'weight': 18},
#  'eocoy': {'weight': 67},
#  'fbuklc': {'supporting': {'klzfl', 'lcyuk'}, 'weight': 82},
#  'ieeqmzl': {'weight': 32},
#  'qcoyrha': {'supporting': {'kjqiop', 'oagluxi'}, 'weight': 255},
#  'lbfgh': {'supporting': {'obaorae', 'yktqkyl'}, 'weight': 123},
#  'payoa': {'supporting': {'khbvu', 'nrxoha'}, 'weight': 194},
#  'ywutc': {'weight': 71},
#  'fodud': {'supporting': {'auvla', 'axmjgih'}, 'weight': 178},
#  'actggv': {'weight': 65},
#  'jngcap': {'supporting': {'ebdxuo', 'ktfeae', 'tydlqpq'}, 'weight': 845},
#  'hcgbmwl': {'weight': 60},
#  'lqirhg': {'supporting': {'hbmxey', 'knhst', 'lxffhxk', 'tlhgrte', 'xekggcw'},
#   'weight': 70965},
#  'ifntl': {'supporting': {'emfbheo',
#    'gcylwr',
#    'heicvby',
#    'qvgeei',
#    'ubrrbmk',
#    'uxuscb',
#    'vcnph'},
#   'weight': 26},
#  'uiasar': {'weight': 15},
#  'sfkzoax': {'weight': 46},
#  'bqtppn': {'supporting': {'fsguvid', 'xqnrp'}, 'weight': 236},
#  'peomyg': {'weight': 16},
#  'sqincn': {'weight': 80},
#  'zjtid': {'weight': 7},
#  'cpvlq': {'weight': 72},
#  'nwbmwa': {'weight': 17},
#  'yjonn': {'supporting': {'bvgfpab', 'cbnef', 'czojwyg', 'rbhdx'},
#   'weight': 185},
#  'jafdtcn': {'weight': 79},
#  'uqofam': {'supporting': {'lxpshey', 'qwdppks'}, 'weight': 245},
#  'nkejtw': {'weight': 56},
#  'tcihaf': {'weight': 28},
#  'jwkgg': {'weight': 17},
#  'hsftfol': {'weight': 46},
#  'ehqavsc': {'supporting': {'aboilvw',
#    'diavsdh',
#    'mtxzcd',
#    'nuybvi',
#    'tulxdf',
#    'wyule',
#    'ziyyvk'},
#   'weight': 22},
#  'dyveac': {'supporting': {'jdsdqzd', 'lhmjc'}, 'weight': 96},
#  'yfztc': {'weight': 74},
#  'nuybvi': {'weight': 452},
#  'ymfosm': {'supporting': {'ckafg', 'dmzwm', 'hdkpuyx'}, 'weight': 38},
#  'vrjea': {'supporting': {'hemnmbr', 'stcaf', 'zuxvjpc'}, 'weight': 1809},
#  'qteruty': {'supporting': {'mwtusu', 'pvpyhb'}, 'weight': 8},
#  'cpmcrx': {'weight': 13},
#  'ouxjkf': {'weight': 18},
#  'rvuktmb': {'supporting': {'cwgbjaq', 'yhlbg'}, 'weight': 147},
#  'blrzef': {'weight': 81},
#  'guxwd': {'weight': 49},
#  'yyyqzje': {'supporting': {'fnfiur', 'jfngjl'}, 'weight': 225},
#  'qbkipp': {'weight': 92},
#  'wdlwryo': {'supporting': {'iltti', 'nxhetg'}, 'weight': 149},
#  'tjdap': {'weight': 240},
#  'udxegjf': {'supporting': {'atfpsi',
#    'lzbbin',
#    'skotajh',
#    'tuqzsn',
#    'ytnti',
#    'zdade'},
#   'weight': 44},
#  'aeliqqs': {'weight': 26},
#  'shkfk': {'weight': 183},
#  'adueu': {'weight': 372},
#  'zbhahq': {'weight': 10},
#  'jbtzoy': {'weight': 80},
#  'pkcakwk': {'weight': 300},
#  'hwkwp': {'weight': 67},
#  'gatxz': {'weight': 45},
#  'qizvid': {'weight': 38},
#  'cbqebx': {'supporting': {'ornybn', 'zcfswa'}, 'weight': 152},
#  'ppmjzx': {'supporting': {'csqyn', 'sfkzoax', 'whlfwr'}, 'weight': 267},
#  'rwuxn': {'weight': 23},
#  'pcdtne': {'supporting': {'adhilml',
#    'alqog',
#    'cujhtj',
#    'fbuhz',
#    'fttsg',
#    'gblxcsj',
#    'hanbscg'},
#   'weight': 6},
#  'fvfitqc': {'weight': 39},
#  'rgfur': {'supporting': {'aswpgvv', 'qgnah'}, 'weight': 104},
#  'jhgxtg': {'weight': 57},
#  'pkotpki': {'weight': 86},
#  'ujzjt': {'weight': 92},
#  'zkikhk': {'weight': 16},
#  'skotajh': {'weight': 328},
#  'ycinfxk': {'supporting': {'bztor', 'cwvkon', 'kosxb', 'nyxiai'},
#   'weight': 1450},
#  'gnffzh': {'supporting': {'sfoivjz', 'tiiwbg'}, 'weight': 234},
#  'juvwj': {'weight': 79},
#  'ckcaugr': {'supporting': {'xuxlspe', 'zebdkqz'}, 'weight': 62},
#  'gjfkx': {'weight': 31},
#  'blome': {'supporting': {'bljfcim', 'jjmyu'}, 'weight': 73},
#  'yqctq': {'weight': 28},
#  'gpzaa': {'supporting': {'cjkoxak', 'lxxfgli', 'sqfopc', 'yyyqzje'},
#   'weight': 68},
#  'qoipc': {'supporting': {'oydoajo', 'tjcpka'}, 'weight': 68},
#  'olhuxt': {'weight': 7},
#  'zdade': {'supporting': {'bvock', 'oyfob'}, 'weight': 166},
#  'ihllda': {'weight': 81},
#  'sbklnq': {'weight': 85},
#  'yyblsz': {'supporting': {'bppos', 'dszjyr', 'nrmvc', 'tahstqe'},
#   'weight': 54},
#  'qenjyl': {'weight': 79},
#  'zukgdrx': {'weight': 79},
#  'fszrgv': {'weight': 34},
#  'ulezwmd': {'weight': 56},
#  'xgogpx': {'weight': 23},
#  'gwxkdy': {'weight': 46},
#  'knhst': {'supporting': {'ghjpcv', 'ojtrl', 'szvrql'}, 'weight': 5583},
#  'mblvffb': {'weight': 79},
#  'qowyx': {'weight': 56},
#  'yablonq': {'weight': 18},
#  'mwfryd': {'supporting': {'kzjfme', 'kzwbhrg', 'mldkiku', 'sveuu'},
#   'weight': 93},
#  'xjafd': {'weight': 17},
#  'njgzn': {'weight': 97},
#  'jpeprwv': {'weight': 12},
#  'lnnii': {'weight': 18},
#  'tsetywu': {'weight': 22},
#  'gdutjjl': {'weight': 73},
#  'lnsyuz': {'weight': 27},
#  'qyypm': {'supporting': {'ajpujs', 'uqofam', 'xtvyh'}, 'weight': 417},
#  'uutlw': {'weight': 75},
#  'cbnef': {'weight': 15},
#  'gikqie': {'supporting': {'lftlpr', 'pxhbe', 'qpwfl', 'yxcbn'}, 'weight': 90},
#  'nkuesm': {'weight': 60},
#  'znpqzc': {'supporting': {'ajtkddh', 'ekxdjlp', 'nkuesm', 'skvytv'},
#   'weight': 53},
#  'mszwp': {'supporting': {'otljqmh', 'qaszsa', 'tupro'}, 'weight': 53},
#  'stcaf': {'supporting': {'cufaveh', 'foblbqu'}, 'weight': 54},
#  'nmlykny': {'supporting': {'lsfdgam', 'uitef'}, 'weight': 112},
#  'frlmoih': {'weight': 92},
#  'hqvvrd': {'supporting': {'ayafxml', 'juvwj'}, 'weight': 34},
#  'unzzng': {'weight': 22},
#  'xucelzn': {'supporting': {'ilzwrk', 'jumdfk'}, 'weight': 49},
#  'nyjmiyq': {'weight': 91},
#  'zfjpii': {'supporting': {'btjxv', 'digfyo', 'rfhjgxy'}, 'weight': 181},
#  'vyvcb': {'supporting': {'jsniger', 'kvtvmi', 'ogiie', 'rbmmiy', 'zvildgh'},
#   'weight': 4479},
#  'fwqru': {'weight': 62},
#  'skvytv': {'weight': 60},
#  'ujogppt': {'weight': 95},
#  'mgzotal': {'supporting': {'frgot', 'sjcbxp'}, 'weight': 125},
#  'ytpiey': {'weight': 83},
#  'bfqba': {'supporting': {'gfknji', 'iwdesog', 'lxisjl', 'qteruty', 'vopeoj'},
#   'weight': 872},
#  'foblbqu': {'weight': 20},
#  'bzlgar': {'weight': 37},
#  'dszjyr': {'weight': 37},
#  'nrpyfqd': {'supporting': {'acjtwvt', 'nihmyu'}, 'weight': 39},
#  'vgvvr': {'weight': 66},
#  'hzsgvc': {'weight': 8},
#  'lddiw': {'weight': 7},
#  'ydhfmt': {'weight': 10},
#  'uspvnv': {'weight': 94},
#  'seazs': {'weight': 92},
#  'zrydf': {'supporting': {'ppbevc', 'zzavd'}, 'weight': 108},
#  'pkglsge': {'weight': 93},
#  'oamrbi': {'weight': 33},
#  'bendlfs': {'weight': 92},
#  'rkgxu': {'weight': 88},
#  'fqhag': {'supporting': {'crojfnw', 'njrzjdt', 'vangx'}, 'weight': 2673},
#  'wesyh': {'weight': 26},
#  'jbaazop': {'weight': 19},
#  'tgvdjhh': {'weight': 72},
#  'ebdxuo': {'weight': 242},
#  'xthhlfy': {'supporting': {'jafdtcn', 'kbout'}, 'weight': 61},
#  'vlthh': {'weight': 88},
#  'sqfrw': {'supporting': {'ppmjzx', 'ryskzh', 'vixlf', 'ynkkomw'},
#   'weight': 830},
#  'kzjfme': {'weight': 55},
#  'heicvby': {'supporting': {'akrsjfc', 'lnhiiq'}, 'weight': 145},
#  'cuaect': {'supporting': {'ftdkas', 'jwgjnuu'}, 'weight': 114},
#  'oyjtku': {'weight': 93},
#  'eyozeel': {'weight': 99},
#  'rfhjgxy': {'weight': 227},
#  'eoasnfq': {'supporting': {'idszh', 'vshekb'}, 'weight': 94},
#  'phgkg': {'weight': 30},
#  'dxgnqsj': {'weight': 34},
#  'egrga': {'supporting': {'cfmhi', 'nrpyfqd', 'uwpwbgy', 'zqtok'},
#   'weight': 1130},
#  'sljgt': {'supporting': {'igfjvkm', 'iifltp', 'rxefab'}, 'weight': 1013},
#  'bszcup': {'weight': 56},
#  'kkyfjh': {'weight': 83},
#  'frvmu': {'supporting': {'vwhynu', 'xdnuvji'}, 'weight': 143},
#  'fsbojm': {'weight': 41},
#  'mavbgo': {'weight': 91},
#  'digfyo': {'supporting': {'swsffrv', 'tkejpfe', 'ynirne'}, 'weight': 188},
#  'xoyjtol': {'weight': 59},
#  'qvbuj': {'supporting': {'dgumiir', 'mkucbvs', 'ofnmnyy'}, 'weight': 1045},
#  'dzetsz': {'supporting': {'krdlzf', 'nsbli', 'ulxsa'}, 'weight': 1418},
#  'zguqo': {'supporting': {'oenrkia', 'ripgc'}, 'weight': 92},
#  'klgsk': {'weight': 6},
#  'yktqkyl': {'weight': 45},
#  'jhcurc': {'weight': 50},
#  'teuzi': {'weight': 57},
#  'gfknji': {'supporting': {'nwyftp', 'vgndgst'}, 'weight': 26},
#  'gcylwr': {'supporting': {'lsycscb', 'wesyh'}, 'weight': 221},
#  'hxaza': {'weight': 7},
#  'asoirn': {'weight': 74},
#  'ofnmnyy': {'supporting': {'sziwpzi', 'zyxjqs'}, 'weight': 36},
#  'xobyzo': {'weight': 60},
#  'azdklp': {'weight': 43},
#  'mcfst': {'weight': 47},
#  'vwqog': {'weight': 43},
#  'tupro': {'weight': 94},
#  'lytukj': {'weight': 25},
#  'roqnodm': {'supporting': {'oxewutr', 'pdcaqbr', 'qbbmsf'}, 'weight': 92},
#  'axmjgih': {'weight': 65},
#  'ezztp': {'weight': 87},
#  'luuxtc': {'supporting': {'dxznun', 'qfkka'}, 'weight': 2600},
#  'pvzyops': {'supporting': {'ffrilz', 'oiyxr', 'upiow'}, 'weight': 94},
#  'adasbyp': {'supporting': {'kdqslsn', 'xantdh'}, 'weight': 237},
#  'iaiywwa': {'supporting': {'boiic', 'kqgqdyg', 'nhxfu'}, 'weight': 1850},
#  'zdkil': {'supporting': {'bgctgn', 'cemygp'}, 'weight': 214},
#  'pslyfi': {'supporting': {'birahww', 'ilydn', 'yfztc'}, 'weight': 7},
#  'wbllfh': {'supporting': {'gprznw', 'xwmnaj'}, 'weight': 43},
#  'drnyyes': {'weight': 66},
#  'coyroy': {'supporting': {'klyso', 'oevvote', 'pirivl', 'zzwtuu'},
#   'weight': 175},
#  'ddkgzi': {'weight': 19},
#  'btbses': {'weight': 88},
#  'mhassfj': {'weight': 9},
#  'rbhdx': {'weight': 15},
#  'kfhwxyy': {'weight': 17},
#  'ozwaa': {'weight': 78},
#  'lhmjc': {'weight': 32},
#  'lftlpr': {'weight': 11},
#  'ncaoc': {'weight': 58},
#  'zacywmu': {'weight': 12},
#  'vixlf': {'supporting': {'cgdbu', 'djmoed', 'eisrj', 'npfkpts'},
#   'weight': 45},
#  'vwtmps': {'supporting': {'jljnags', 'qizvid'}, 'weight': 142},
#  'fsguvid': {'weight': 33},
#  'gxdtiob': {'supporting': {'bzkwsro', 'gzter', 'vbisx'}, 'weight': 203},
#  'xwphya': {'weight': 82},
#  'jtujnwo': {'weight': 37},
#  'wyule': {'supporting': {'jwkgg', 'nwbmwa', 'pvpqoq'}, 'weight': 401},
#  'wpgyc': {'weight': 96},
#  'jbvugg': {'supporting': {'dxgnqsj', 'fsfuluo'}, 'weight': 224},
#  'tojnst': {'weight': 160},
#  'jeshqdv': {'supporting': {'affxphr', 'cqdtav', 'lyhxuh', 'zkcwgx'},
#   'weight': 1303},
#  'icncbl': {'weight': 48},
#  'kqiraxg': {'weight': 54},
#  'aicncxc': {'weight': 29},
#  'zbedu': {'weight': 209},
#  'pdmsm': {'weight': 57},
#  'kictlpo': {'weight': 37},
#  'brkux': {'weight': 335},
#  'zrbkrdx': {'weight': 41},
#  'otljqmh': {'weight': 94},
#  'kcreb': {'supporting': {'bvaor', 'ihuzl', 'popymuq'}, 'weight': 48},
#  'muavtro': {'weight': 98},
#  'ayypg': {'weight': 56},
#  'vdistyb': {'weight': 90},
#  'euvkg': {'supporting': {'lazlx', 'mgwauar'}, 'weight': 203},
#  'ayafxml': {'weight': 79},
#  'bnvjmae': {'weight': 7},
#  'ogpka': {'weight': 80},
#  'gnrqrsj': {'supporting': {'ortcrq', 'upbmqk'}, 'weight': 2189},
#  'rxefab': {'supporting': {'sqnfwo', 'vcaekf'}, 'weight': 131},
#  'pgpnvo': {'supporting': {'bbdimns', 'eahos', 'kcreb', 'lwefm'},
#   'weight': 931},
#  'bphrvm': {'weight': 64},
#  'doazn': {'supporting': {'hhvqa', 'siswh'}, 'weight': 211},
#  'sawqp': {'weight': 32},
#  'mwdvbr': {'weight': 68},
#  'mtboq': {'weight': 76},
#  'dxcpj': {'supporting': {'afcgdxg', 'kzwgln', 'spkeqv', 'udxegjf', 'wkydaz'},
#   'weight': 93},
#  'lyhxuh': {'weight': 22},
#  'iuovz': {'weight': 88},
#  'csear': {'supporting': {'evmblgk', 'fnijmph', 'mgzotal'}, 'weight': 1969},
#  'rojhup': {'weight': 7},
#  'ebtbnei': {'weight': 31},
#  'lhnevgo': {'weight': 269},
#  'zibbm': {'weight': 85},
#  'nrmvc': {'weight': 37},
#  'txxpej': {'supporting': {'actggv', 'krqxe'}, 'weight': 280},
#  'lhvtmoo': {'supporting': {'icncbl', 'zbtck'}, 'weight': 130},
#  'wgwkss': {'weight': 80},
#  'aawxzzs': {'weight': 22},
#  'aarioi': {'weight': 79},
#  'cabsaub': {'weight': 60},
#  'otymybu': {'supporting': {'ddkgzi', 'viafs'}, 'weight': 223},
#  'cbgfg': {'weight': 58},
#  ...}

# %%
nonRoot_set=set()
for vals in disks_dict.values():
    nonRoot_set=nonRoot_set.union(vals.get('supporting', {}))
nonRoot_set

rootDisk_str=(set(disk for disk in disks_dict)-nonRoot_set).pop()
rootDisk_str
# Out:
# 'hlhomy'

# %%
set_total_weights(rootDisk_str, disks_dict)
# Out:
# 781448

# %%
(d, c)=find_incorrect_disk(rootDisk_str, disks_dict)
d
# Out:
# 'apjxafk'

# %%
disks_dict[d]['weight']+c
# Out:
# 1505
